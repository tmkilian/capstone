# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# This notebook is meant to be a venue for looking at the housing datasets for my General Assembly capstone project.
#
# In this project I hope to analyze and target the housing (rental?) prices for San Francisco (and maybe another city). Instead of simply using housing prices, whether asking/sale prices or posted rental rates, I will try to incorporate the wealth of other information from neighborhoods to factor in a more intelligent pricing scheme. In other words, given a price you can afford, where can you get the best deal. This will try to take into account the specific desires of the buyer/renter specific to regions; i.e. is there a higher preference for living near good food, parks, bars, public transit stops, et cetera?
#
# Below we look through some of the datasets publicly availabe to see what features we use in this project. In most cases it is advantageous to have data points connected to geography - latitude/longitude coordinates included in datasets.

# %% [markdown]
# ## Airbnb data

# %% [markdown]
# These data were downloaded from a third party website that supplies Airbnb sata from cities around the world. An elaborate list of disclaimers is available here (http://insideairbnb.com/about.html#disclaimers). It seems like they took a reasonable approach at cleaning the data, but this should be referenced to be aware of biases.

# %%
bnb_cal = pd.read_csv('../project_data/airbnb_data/calendar.csv')
bnb_listings_sum = pd.read_csv('../project_data/airbnb_data/listings_sum.csv')
bnb_listings = pd.read_csv('../project_data/airbnb_data/listings.csv')
bnb_reviews_sum = pd.read_csv('../project_data/airbnb_data/reviews_sum.csv')
bnb_reviews = pd.read_csv('../project_data/airbnb_data/reviews.csv')

# %%
print bnb_cal.shape
bnb_cal.head()
# Out:
# (3145935, 4)
#    listing_id        date available price
# 0    11187767  2017-03-12         f   NaN
# 1    11187767  2017-03-11         f   NaN
# 2    11187767  2017-03-10         f   NaN
# 3    11187767  2017-03-09         f   NaN
# 4    11187767  2017-03-08         f   NaN

# %% [markdown]
# There are two types of availability, 't' and 'f', not sure what they stand for, but only 't's have prices, making beleive that 't' means true and 'f' means false - probably a safe bet that that is the case. 't' or true must mean that the apartment is unavailable, perhaps it doesn't matter given that the price probably doesn't change much over the course of a month. If there are pricing changes for listings then we can track them month by month or year by year.

# %%
bnb_listings.thumbnail_url.values[0]
# Out:
# 'https://a2.muscache.com/im/pictures/e8652800-ae74-4322-824e-a9c7e5deda63.jpg?aki_policy=small'

# %%
print bnb_listings.shape
bnb_listings.head().T
# Out:
# (8619, 95)
#                                                                                   0  \
# id                                                                         11187767
# listing_url                                   https://www.airbnb.com/rooms/11187767
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                             Huge Seacliff Penthouse With Views
# summary                           Amazing views from this immense 3 bedroom/ 2 b...
# space                             Spacious patio deck, library with over 300 mov...
# description                       Amazing views from this immense 3 bedroom/ 2 b...
# experiences_offered                                                            none
# neighborhood_overview             The neighborhood includes Legion of Honor, Sut...
# notes                             We require a separate rental agreement to be s...
# transit                           Public Transportation including Muni and the B...
# access                            Guests have access to the entire flat includin...
# interaction                         I am available 24 hours a day during your stay.
# house_rules                       1. Smoking is NOT allowed in the Property, Com...
# thumbnail_url                     https://a2.muscache.com/im/pictures/e8652800-a...
# medium_url                        https://a2.muscache.com/im/pictures/e8652800-a...
# picture_url                       https://a2.muscache.com/im/pictures/e8652800-a...
# xl_picture_url                    https://a2.muscache.com/im/pictures/e8652800-a...
# host_id                                                                    58242037
# host_url                                 https://www.airbnb.com/users/show/58242037
# host_name                                                                  Jonathan
# host_since                                                               2016-02-10
# host_location                              San Francisco, California, United States
# host_about                        Property Manager for Watt Property Management,...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                           100%
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a2.muscache.com/im/pictures/351d2fbc-4...
# ...                                                                             ...
# guests_included                                                                   1
# extra_people                                                                  $0.00
# minimum_nights                                                                    2
# maximum_nights                                                                   28
# calendar_updated                                                              today
# has_availability                                                                NaN
# availability_30                                                                   8
# availability_60                                                                  31
# availability_90                                                                  61
# availability_365                                                                152
# calendar_last_scraped                                                    2016-07-02
# number_of_reviews                                                                 3
# first_review                                                             2016-03-23
# last_review                                                              2016-06-25
# review_scores_rating                                                             80
# review_scores_accuracy                                                            9
# review_scores_cleanliness                                                         9
# review_scores_checkin                                                             9
# review_scores_communication                                                       9
# review_scores_location                                                            9
# review_scores_value                                                               8
# requires_license                                                                  t
# license                                                                         NaN
# jurisdiction_names                                                    SAN FRANCISCO
# instant_bookable                                                                  t
# cancellation_policy                                                          strict
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    1
# reviews_per_month                                                              0.88
#
#                                                                                   1  \
# id                                                                          6938818
# listing_url                                    https://www.airbnb.com/rooms/6938818
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                                            Best Secret in Town
# summary                           My two story house is located in the quite sid...
# space                             The room is spacious and it is on the top leve...
# description                       My two story house is located in the quite sid...
# experiences_offered                                                            none
# neighborhood_overview             It is in the city and close to everything. Par...
# notes                             The summer in San Francisco is cooler than any...
# transit                           If you are on budget, the public transportatio...
# access                            You will have full access to your room, bathro...
# interaction                       I may not available in person to assist you du...
# house_rules                       1.  No pets, no smoking inside the house. 2. F...
# thumbnail_url                     https://a2.muscache.com/im/pictures/441473b8-6...
# medium_url                        https://a2.muscache.com/im/pictures/441473b8-6...
# picture_url                       https://a2.muscache.com/im/pictures/441473b8-6...
# xl_picture_url                    https://a2.muscache.com/im/pictures/441473b8-6...
# host_id                                                                    36381578
# host_url                                 https://www.airbnb.com/users/show/36381578
# host_name                                                                    Harris
# host_since                                                               2015-06-21
# host_location                              San Francisco, California, United States
# host_about                        Retired Accounting Professional. Down to earth...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                           100%
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a2.muscache.com/im/pictures/a3435acf-3...
# ...                                                                             ...
# guests_included                                                                   2
# extra_people                                                                 $20.00
# minimum_nights                                                                    3
# maximum_nights                                                                   30
# calendar_updated                                                        2 weeks ago
# has_availability                                                                NaN
# availability_30                                                                   2
# availability_60                                                                   7
# availability_90                                                                   8
# availability_365                                                                187
# calendar_last_scraped                                                    2016-07-02
# number_of_reviews                                                                23
# first_review                                                             2015-06-27
# last_review                                                              2016-06-16
# review_scores_rating                                                             91
# review_scores_accuracy                                                            9
# review_scores_cleanliness                                                         9
# review_scores_checkin                                                            10
# review_scores_communication                                                      10
# review_scores_location                                                            9
# review_scores_value                                                               9
# requires_license                                                                  t
# license                           S. F. Short-Term Residential Rental Registrati...
# jurisdiction_names                                                    SAN FRANCISCO
# instant_bookable                                                                  f
# cancellation_policy                                                          strict
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    2
# reviews_per_month                                                              1.85
#
#                                                                                   2  \
# id                                                                          9395222
# listing_url                                    https://www.airbnb.com/rooms/9395222
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                                  Ocean Beach, Lands End Escape
# summary                           Come relax in our 1 bedroom 1 bath house minut...
# space                             Huge backyard with a FirePit and lounge chairs...
# description                       Come relax in our 1 bedroom 1 bath house minut...
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                                                                           NaN
# transit                           38 Geary stop is 1 block away that will take y...
# access                            Entire 1 bedroom 1 bath, huge backyard and a p...
# interaction                                                                     NaN
# house_rules                       *No smoking please *QUITE HOURS 10pm-9am pleas...
# thumbnail_url                     https://a2.muscache.com/im/pictures/103e2c9f-2...
# medium_url                        https://a2.muscache.com/im/pictures/103e2c9f-2...
# picture_url                       https://a2.muscache.com/im/pictures/103e2c9f-2...
# xl_picture_url                    https://a2.muscache.com/im/pictures/103e2c9f-2...
# host_id                                                                    25963295
# host_url                                 https://www.airbnb.com/users/show/25963295
# host_name                                                                     Tyler
# host_since                                                               2015-01-11
# host_location                              San Francisco, California, United States
# host_about                        My husband and I go back and forth between San...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                            99%
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a2.muscache.com/im/pictures/bf8a0d2e-7...
# ...                                                                             ...
# guests_included                                                                   2
# extra_people                                                                 $10.00
# minimum_nights                                                                    1
# maximum_nights                                                                 1125
# calendar_updated                                                         5 days ago
# has_availability                                                                NaN
# availability_30                                                                   0
# availability_60                                                                   6
# availability_90                                                                  20
# availability_365                                                                167
# calendar_last_scraped                                                    2016-07-02
# number_of_reviews                                                                45
# first_review                                                             2015-11-16
# last_review                                                              2016-06-19
# review_scores_rating                                                             88
# review_scores_accuracy                                                            9
# review_scores_cleanliness                                                         9
# review_scores_checkin                                                            10
# review_scores_communication                                                      10
# review_scores_location                                                           10
# review_scores_value                                                               9
# requires_license                                                                  t
# license                                                                         NaN
# jurisdiction_names                                                    SAN FRANCISCO
# instant_bookable                                                                  t
# cancellation_policy                                                          strict
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    1
# reviews_per_month                                                              5.87
#
#                                                                                   3  \
# id                                                                          8388658
# listing_url                                    https://www.airbnb.com/rooms/8388658
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                            Mid-century Seacliff near GG Bridge
# summary                           Three-bedroom in exclusive Seacliff neighborho...
# space                                                                           NaN
# description                       Three-bedroom in exclusive Seacliff neighborho...
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                                                                           NaN
# transit                                                                         NaN
# access                                                                          NaN
# interaction                                                                     NaN
# house_rules                                                                     NaN
# thumbnail_url                     https://a1.muscache.com/im/pictures/106926931/...
# medium_url                        https://a1.muscache.com/im/pictures/106926931/...
# picture_url                       https://a1.muscache.com/im/pictures/106926931/...
# xl_picture_url                    https://a1.muscache.com/im/pictures/106926931/...
# host_id                                                                     9996441
# host_url                                  https://www.airbnb.com/users/show/9996441
# host_name                                                                    Howard
# host_since                                                               2013-11-13
# host_location                              San Francisco, California, United States
# host_about                        We are a family of four, all avid travelers.  ...
# host_response_time                                                              NaN
# host_response_rate                                                              NaN
# host_acceptance_rate                                                            NaN
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a0.muscache.com/im/users/9996441/profi...
# ...                                                                             ...
# guests_included                                                                   1
# extra_people                                                                  $0.00
# minimum_nights                                                                    3
# maximum_nights                                                                   14
# calendar_updated                                                       6 months ago
# has_availability                                                                NaN
# availability_30                                                                   0
# availability_60                                                                   0
# availability_90                                                                   0
# availability_365                                                                  0
# calendar_last_scraped                                                    2016-07-02
# number_of_reviews                                                                 0
# first_review                                                                    NaN
# last_review                                                                     NaN
# review_scores_rating                                                            NaN
# review_scores_accuracy                                                          NaN
# review_scores_cleanliness                                                       NaN
# review_scores_checkin                                                           NaN
# review_scores_communication                                                     NaN
# review_scores_location                                                          NaN
# review_scores_value                                                             NaN
# requires_license                                                                  t
# license                                                                         NaN
# jurisdiction_names                                                    SAN FRANCISCO
# instant_bookable                                                                  f
# cancellation_policy                                                        flexible
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    1
# reviews_per_month                                                               NaN
#
#                                                                                   4
# id                                                                          7856443
# listing_url                                    https://www.airbnb.com/rooms/7856443
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                                      The Real San Francisco #2
# summary                           Minutes to GG Bridge, GG Park, Museums, The Pr...
# space                             Following the wild popularity of our downstair...
# description                       Minutes to GG Bridge, GG Park, Museums, The Pr...
# experiences_offered                                                            none
# neighborhood_overview             For those who love the outdoors and good food,...
# notes                                                                           NaN
# transit                           STREET PARKING Street parking in our neighborh...
# access                            Guests are permitted access to the entire main...
# interaction                       We'll be gone.  You'll hear some noise/talking...
# house_rules                       We have neighbors (a family) and guests (also ...
# thumbnail_url                     https://a2.muscache.com/im/pictures/6cf5a572-a...
# medium_url                        https://a2.muscache.com/im/pictures/6cf5a572-a...
# picture_url                       https://a2.muscache.com/im/pictures/6cf5a572-a...
# xl_picture_url                    https://a2.muscache.com/im/pictures/6cf5a572-a...
# host_id                                                                     6076870
# host_url                                  https://www.airbnb.com/users/show/6076870
# host_name                                                          Todd And Tatyana
# host_since                                                               2013-04-24
# host_location                              San Francisco, California, United States
# host_about                        We're backpackers at heart.  We've bagged over...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                           100%
# host_is_superhost                                                                 t
# host_thumbnail_url                https://a1.muscache.com/im/users/6076870/profi...
# ...                                                                             ...
# guests_included                                                                   1
# extra_people                                                                  $0.00
# minimum_nights                                                                    2
# maximum_nights                                                                 1125
# calendar_updated                                                         6 days ago
# has_availability                                                                NaN
# availability_30                                                                   2
# availability_60                                                                   2
# availability_90                                                                   9
# availability_365                                                                 23
# calendar_last_scraped                                                    2016-07-02
# number_of_reviews                                                                 4
# first_review                                                             2016-05-15
# last_review                                                              2016-06-22
# review_scores_rating                                                            100
# review_scores_accuracy                                                           10
# review_scores_cleanliness                                                        10
# review_scores_checkin                                                            10
# review_scores_communication                                                      10
# review_scores_location                                                           10
# review_scores_value                                                              10
# requires_license                                                                  t
# license                                                                         NaN
# jurisdiction_names                                                    SAN FRANCISCO
# instant_bookable                                                                  f
# cancellation_policy                                                          strict
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    2
# reviews_per_month                                                              2.45
#
# [95 rows x 5 columns]

# %%
bnb_cal.price.value_counts(dropna=False).head(10)
# Out:
# NaN        1909112
# $150.00      45065
# $200.00      35702
# $250.00      33873
# $100.00      28943
# $300.00      28324
# $125.00      27444
# $175.00      24212
# $120.00      21745
# $350.00      20088
# Name: price, dtype: int64

# %%
def conv_to_float(s):
    if s:
        return float(s)
    else:
        return s

# %%
bnb_cal['price'] = bnb_cal.price.replace(to_replace=r'[^0-9.]+', value='', regex=True, )
bnb_cal['price'] = bnb_cal.price.apply(conv_to_float, convert_dtype=True)
bnb_cal.price.value_counts(dropna=False).head(10)
# Out:
# NaN       1909112
#  150.0      45065
#  200.0      35702
#  250.0      33873
#  100.0      28943
#  300.0      28324
#  125.0      27444
#  175.0      24212
#  120.0      21745
#  350.0      20088
# Name: price, dtype: int64

# %%
bnb_cal.price.hist(bins=300,)
plt.xlim((0, 2000))
# Out:
# (0, 2000)

# %%
bnb_cal.iloc[17500]
# Out:
# listing_id      13590516
# date          2016-07-21
# available              t
# price                735
# Name: 17500, dtype: object

# %% [markdown]
# The Airbnb calendar dataset gives a list of prices for the listings over the past year. If the unit is available for rent, a price is listed. Some listings have the same price over the entire year and other listings have different pricing schemes for certain periods of time. Below, I show a listing that is $90 more expensive on weekends. This may also be the case for some listings over holiday periods or popular vacation times (e.g. spring break or Memorial Day).

# %%
print bnb_cal[bnb_cal.listing_id == 13590516].shape
bnb_cal[bnb_cal.listing_id == 13590516].head()
# Out:
# (365, 4)
#        listing_id        date available  price
# 17155    13590516  2017-07-01         t  525.0
# 17156    13590516  2017-06-30         t  525.0
# 17157    13590516  2017-06-29         t  434.0
# 17158    13590516  2017-06-28         t  434.0
# 17159    13590516  2017-06-27         t  434.0

# %%
print bnb_listings_sum.shape
bnb_listings_sum.head().T
# Out:
# (8619, 16)
#                                                                  0  \
# id                                                        11187767
# name                            Huge Seacliff Penthouse With Views
# host_id                                                   58242037
# host_name                                                 Jonathan
# neighbourhood_group                                            NaN
# neighbourhood                                             Seacliff
# latitude                                                   37.7797
# longitude                                                  -122.51
# room_type                                          Entire home/apt
# price                                                          400
# minimum_nights                                                   2
# number_of_reviews                                                3
# last_review                                             2016-06-25
# reviews_per_month                                             0.88
# calculated_host_listings_count                                   1
# availability_365                                               152
#
#                                                   1  \
# id                                          6938818
# name                            Best Secret in Town
# host_id                                    36381578
# host_name                                    Harris
# neighbourhood_group                             NaN
# neighbourhood                              Seacliff
# latitude                                    37.7807
# longitude                                  -122.506
# room_type                              Private room
# price                                            99
# minimum_nights                                    3
# number_of_reviews                                23
# last_review                              2016-06-16
# reviews_per_month                              1.85
# calculated_host_listings_count                    2
# availability_365                                187
#
#                                                             2  \
# id                                                    9395222
# name                            Ocean Beach, Lands End Escape
# host_id                                              25963295
# host_name                                               Tyler
# neighbourhood_group                                       NaN
# neighbourhood                                        Seacliff
# latitude                                              37.7814
# longitude                                            -122.505
# room_type                                     Entire home/apt
# price                                                     155
# minimum_nights                                              1
# number_of_reviews                                          45
# last_review                                        2016-06-19
# reviews_per_month                                        5.87
# calculated_host_listings_count                              1
# availability_365                                          167
#
#                                                                   3  \
# id                                                          8388658
# name                            Mid-century Seacliff near GG Bridge
# host_id                                                     9996441
# host_name                                                    Howard
# neighbourhood_group                                             NaN
# neighbourhood                                              Seacliff
# latitude                                                    37.7877
# longitude                                                  -122.489
# room_type                                           Entire home/apt
# price                                                           895
# minimum_nights                                                    3
# number_of_reviews                                                 0
# last_review                                                     NaN
# reviews_per_month                                               NaN
# calculated_host_listings_count                                    1
# availability_365                                                  0
#
#                                                         4
# id                                                7856443
# name                            The Real San Francisco #2
# host_id                                           6076870
# host_name                                Todd And Tatyana
# neighbourhood_group                                   NaN
# neighbourhood                                    Seacliff
# latitude                                          37.7821
# longitude                                        -122.493
# room_type                                 Entire home/apt
# price                                                 195
# minimum_nights                                          2
# number_of_reviews                                       4
# last_review                                    2016-06-22
# reviews_per_month                                    2.45
# calculated_host_listings_count                          2
# availability_365                                       23

# %%
bnb_reviews.listing_id.unique().shape
# Out:
# (6396,)

# %%
print bnb_reviews.shape
bnb_reviews.head()
# Out:
# (169739, 6)
#    listing_id        id        date  reviewer_id      reviewer_name  \
# 0     8308113  47419975  2015-09-18      6288054              Colin
# 1     3320213  14805088  2014-06-26     17101713               Faye
# 2     3320213  17192435  2014-08-08       182792  Jocelyne & Pontus
# 3     3320213  17597907  2014-08-14     19649465          Francesco
# 4     3320213  18293826  2014-08-24      1104165             Daniel
#
#                                             comments
# 0  Host was excellent and was contactable / respo...
# 1  The place was clean and spacious and the guy t...
# 2  This place wasn't as pleasant as we hoped. Had...
# 3  Si tratta di una piccola pensione/albergo.\nSt...
# 4  Nice room, cool neighbourhood. Note that this ...

# %%
print bnb_reviews_sum.shape
bnb_reviews_sum.head()
# Out:
# (169739, 2)
#    listing_id        date
# 0     8308113  2015-09-18
# 1     3320213  2014-06-26
# 2     3320213  2014-08-08
# 3     3320213  2014-08-14
# 4     3320213  2014-08-24

# %%
bnb_reviews_sum.date.value_counts()
# Out:
# 2015-09-21    569
# 2016-05-30    491
# 2016-05-15    489
# 2015-08-07    487
# 2016-06-10    486
# 2016-05-23    465
# 2016-05-22    464
# 2015-09-18    461
# 2016-06-09    459
# 2016-06-17    453
# 2016-05-16    452
# 2016-05-08    445
# 2016-04-11    445
# 2016-02-08    442
# 2016-02-15    438
# 2015-10-24    438
# 2016-03-17    432
# 2016-06-18    429
# 2016-06-13    420
# 2016-05-28    414
# 2015-09-19    412
# 2016-04-04    406
# 2015-08-10    405
# 2016-05-18    404
# 2016-04-01    402
# 2016-03-19    401
# 2016-06-19    397
# 2016-03-20    396
# 2016-05-31    392
# 2016-05-21    391
#              ...
# 2011-03-23      1
# 2011-03-24      1
# 2011-10-15      1
# 2010-10-30      1
# 2009-09-14      1
# 2011-02-27      1
# 2010-07-31      1
# 2010-07-30      1
# 2009-09-11      1
# 2009-09-12      1
# 2010-09-03      1
# 2009-10-03      1
# 2009-10-05      1
# 2010-10-16      1
# 2009-10-08      1
# 2009-07-15      1
# 2010-02-13      1
# 2010-02-17      1
# 2010-03-30      1
# 2010-02-15      1
# 2010-02-14      1
# 2010-02-18      1
# 2011-01-12      1
# 2011-03-02      1
# 2010-07-07      1
# 2010-07-06      1
# 2010-02-28      1
# 2009-09-06      1
# 2010-11-10      1
# 2009-05-23      1
# Name: date, dtype: int64

# %% [markdown]
# ## SF city data

# %% [markdown]
# ### 311 records

# %%
rec_311 = pd.read_csv('../project_data/sf_city_data/311_case_records/311_records.csv')
# Out:
# /Users/taylorkilian/anaconda3/envs/dsi/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print rec_311.shape
rec_311.head()
# Out:
# (1821839, 16)
#    CaseID                  Opened                  Closed  \
# 0  322571  11/30/2008 11:53:00 PM  12/01/2008 03:19:00 PM
# 1  322568  11/30/2008 11:13:00 PM  07/21/2009 04:24:00 PM
# 2  322567  11/30/2008 11:07:00 PM  12/27/2008 06:07:00 AM
# 3  322566  11/30/2008 10:56:00 PM  07/21/2009 04:24:00 PM
# 4  322565  11/30/2008 10:46:00 PM  12/13/2008 10:50:00 AM
#
#                   Updated  Status Status Notes  \
# 0  12/01/2008 03:19:00 PM  Closed          NaN
# 1  07/21/2009 04:24:00 PM  Closed          NaN
# 2  12/27/2008 06:07:00 AM  Closed          NaN
# 3  07/21/2009 04:24:00 PM  Closed          NaN
# 4  12/13/2008 10:50:00 AM  Closed          NaN
#
#                 Responsible Agency                      Category  \
# 0         PUC - Electric/Power - G              General Requests
# 1                    DPW Ops Queue              Illegal Postings
# 2                    DPW Ops Queue              Illegal Postings
# 3                    DPW Ops Queue  Street and Sidewalk Cleaning
# 4  RPD Park Service Area GGP Queue         Rec and Park Requests
#
#                                    Request Type  \
# 0          puc - electric - request_for_service
# 1  Illegal Postings - Posting_Too_Large_in_Size
# 2         Illegal Postings - Affixed_Improperly
# 3                             Sidewalk_Cleaning
# 4                 Park - Structural_Maintenance
#
#                          Request Details  \
# 0   puc - electric - request_for_service
# 1  Posting_Too_Large_in_Size on Sidewalk
# 2         Affixed_Improperly on Sidewalk
# 3                                Garbage
# 4                                  Other
#
#                                       Address  Supervisor District  \
# 0         Intersection of 21ST ST and CAPP ST                    9
# 1    Intersection of BUSH ST and VAN NESS AVE                    3
# 2  Intersection of EUCLID AVE and MASONIC AVE                    2
# 3      1566 HYDE ST, SAN FRANCISCO, CA, 94109                    3
# 4     GGP Panhandle, SAN FRANCISCO, CA, 94117                    5
#
#        Neighborhood                                  Point    Source Media URL
# 0           Mission  (37.7571008516766, -122.417811874214)  Voice In       NaN
# 1          Nob Hill  (37.7884895281133, -122.421948485141)  Voice In       NaN
# 2  Western Addition  (37.7850837365507, -122.447620029034)  Voice In       NaN
# 3          Nob Hill         (37.795328529, -122.418067787)  Voice In       NaN
# 4    Haight Ashbury           (37.772204762, -122.4487004)  Voice In       NaN

# %% [markdown]
# Data back to 2008 - need to double check this after converting date ranges to datetime objects.

# %%
rec_311.Category.value_counts()
# Out:
# Street and Sidewalk Cleaning    636346
# Graffiti Public Property        173169
# General Requests                133050
# Graffiti Private Property       132591
# Abandoned Vehicle               129793
# Damaged Property                 71597
# SFHA Requests                    64117
# Sewer Issues                     58085
# Streetlights                     48497
# Tree Maintenance                 45370
# MUNI Feedback                    43864
# Street Defects                   39155
# Litter Receptacles               37458
# Illegal Postings                 35902
# Sign Repair                      32613
# Rec and Park Requests            30541
# Sidewalk or Curb                 27904
# Temporary Sign Request           24892
# 311 External Request             17156
# Blocked Street or SideWalk       14565
# Residential Building Request      7950
# Color Curb                        5372
# Catch Basin Maintenance           4852
# Noise Report                      2955
# Construction Zone Permits         2044
# Interdepartmental Request         1293
# Unpermitted Cab Complaint          387
# DPW Volunteer Programs             321
# Name: Category, dtype: int64

# %%
rec_311['Request Type'].value_counts()
# Out:
# Sidewalk_Cleaning                                                                                171694
# Bulky Items                                                                                      144358
# General Cleaning                                                                                 143973
# Not_Offensive Graffiti on Private Property                                                       100851
# Offensive Graffiti on Public Property                                                             95348
# Not_Offensive Graffiti on Public Property                                                         77386
# Hazardous Materials                                                                               63864
# Damaged Parking_Meter                                                                             52767
# Illegal_Dumping                                                                                   44598
# Abandoned Vehicle - Car4door                                                                      41956
# Pavement_Defect                                                                                   34099
# SFHA Priority - Urgent                                                                            31781
# Sewage_back_up                                                                                    29913
# Streetlight - Light_Burnt_Out                                                                     29697
# Illegal Encampment                                                                                27566
# Offensive Graffiti on Private Property                                                            26731
# Abandoned Vehicle - Other                                                                         26150
# Abandoned Vehicle - Car2door                                                                      20058
# Sidewalk_Defect                                                                                   19204
# SFHA Priority - Emergency                                                                         17822
# Street_Cleaning                                                                                   17521
# Sign - Defaced                                                                                    17151
# Trees - Damaged_Tree                                                                              15786
# Cans_Left_Out_24x7                                                                                15264
# Temporary Sign Request for Moving_residential_property                                            14569
# Abandoned Vehicle - PickupTruck                                                                   13936
# Park - Structural_Maintenance                                                                     13387
# SFHA Priority - Routine                                                                           12807
# Trees - Overgrown_Tree                                                                            11595
# Damaged Traffic_Signal                                                                            11534
#                                                                                                   ...
# Construction Zone Tow-away Permits for John Anderson                                                  1
# economics_and_workforce_development - economics_and_workforce_development - customer_callback         1
# Construction Zone Tow-away Permits for Creative Roots                                                 1
# Construction Zone Tow-away Permits for West Builders                                                  1
# Construction Zone Tow-away Permits for Ghilotti Brothers                                              1
# Construction Zone Tow-away Permits for Adan Flores                                                    1
# Volunteer                                                                                             1
# human_rights_commission - human_rights_commission - mailing_request                                   1
# Construction Zone Tow-away Permits for Synergy Project Management                                     1
# Construction Zone Tow-away Permits for Martin Painting                                                1
# assessor_recorder - recorder - complaint                                                              1
# small_business - small_business - mailing_request                                                     1
# rpd - graffiti - complaint                                                                            1
# Construction Zone Tow-away Permits for Shimack Construction                                           1
# Value5                                                                                                1
# Value1                                                                                                1
# Construction Zone Tow-away Permits for JBD CONSTRUCTION                                               1
# building_inspection - housing_inspection - compliment                                                 1
# mta - sign_shop - mailing_request                                                                     1
# county_clerk -  - request_for_service                                                                 1
# film_commission - film_commission - other                                                             1
# dph - chn - mailing_request                                                                           1
# Construction Zone Tow-away Permits for DTIS                                                           1
# aging_adult_services - aging_adult_services - mailing_request                                         1
# Construction Zone Tow-away Permits for                                                                1
# juvenile_probation - juvenile_probation - request_for_service                                         1
# Construction Zone Tow-away Permits for Flores General Construction                                    1
# Landscaping - SprinklerSystemIssues                                                                   1
# human_services_agency - calworks - complaint                                                          1
# assessor_recorder - assessor_recorder_re_watchdog_program - followup_request                          1
# Name: Request Type, dtype: int64

# %% [markdown]
# Lots of geolocated data to play around with...

# %% [markdown]
# ### Parks
#
# 'Park_info.csv' contains geolocated information about the many parks in San Francisco.
#
# 'park_scores.csv' contains scores for the various parks. Need to figure out exactly how these scores are given, but can like with the geolocations of the actual parks to see which parks people may like more - these would be better to live next to, if it's important to you.

# %%
park_info = pd.read_csv('../project_data/sf_city_data/parks/park_info.csv')
park_scores = pd.read_csv('../project_data/sf_city_data/parks/park_scores.csv')

# %%
print park_info.shape
park_info.head()
# Out:
# (230, 12)
#                      ParkName                         ParkType  \
# 0                    ParkName                         ParkType
# 1  10TH AVE/CLEMENT MINI PARK                        Mini Park
# 2           15TH AVENUE STEPS                        Mini Park
# 3         24TH/YORK MINI PARK                        Mini Park
# 4     29TH/DIAMOND OPEN SPACE  Neighborhood Park or Playground
#
#    ParkServiceArea       PSAManager                     email          Number  \
# 0  ParkServiceArea       PSAManager                     email          Number
# 1            PSA 1     Elder, Steve    steven.elder@sfgov.org  (415) 601-6501
# 2            PSA 4    Sheehy, Chuck  charles.sheehy@sfgov.org  (415) 218-2226
# 3            PSA 6    Field, Adrian    adrian.field@sfgov.org  (415) 717-2872
# 4            PSA 5  O'Brien, Teresa  teresa.o'brien@sfgov.org  (415) 819-2699
#
#    Zipcode  Acreage  SupDist  ParkID  \
# 0      NaN      NaN      NaN     NaN
# 1  94118.0     0.66      1.0   156.0
# 2  94122.0     0.26      7.0   185.0
# 3  94110.0     0.12      9.0    51.0
# 4  94131.0     0.82      8.0   194.0
#
#                                           Location 1  Lat
# 0                                                NaN  NaN
# 1  351 9th Ave\nSan Francisco, CA\n(37.78184397, ...  NaN
# 2  15th Ave b w Kirkham\nSan Francisco, CA\n(37.7...  NaN
# 3  24th\nSan Francisco, CA\n(37.75306042, -122.40...  NaN
# 4  Diamond\nSan Francisco, CA\n(37.74360211, -122...  NaN

# %%
park_info.loc[1,'Location 1']
# Out:
# '351 9th Ave\nSan Francisco, CA\n(37.78184397, -122.46809908)'

# %%
print park_scores.shape
park_scores.head()
# Out:
# (5495, 5)
#    ParkID   PSA                       Park      FQ  Score
# 0      86  PSA4           Carl Larsen Park  FY05Q3  0.795
# 1      13  PSA4  Junipero Serra Playground  FY05Q3  0.957
# 2       9  PSA4     Rolph Nicol Playground  FY05Q3  0.864
# 3     117  PSA2               Alamo Square  FY05Q4  0.857
# 4      60  PSA6   Jose Coronado Playground  FY05Q4  0.859

# %% [markdown]
# ### SF crime data

# %% [markdown]
# San Francisco provides data on crimes (or SFPD incidents) back to 2003. This time frame may need to be adjusted so that possible estimators are current.

# %%
crimes_sf = pd.read_csv('../project_data/sf_city_data/sf_crime/sfpd_incidents_from2003.csv')

# %%
print crimes_sf.shape
crimes_sf.head()
# Out:
# (1945294, 13)
#    IncidntNum        Category                     Descript DayOfWeek  \
# 0   110914565        WARRANTS               WARRANT ARREST    Friday
# 1    11351210  MISSING PERSON                 FOUND PERSON   Tuesday
# 2   120789988  MISSING PERSON                 FOUND PERSON    Monday
# 3   140608681         ROBBERY        ROBBERY, BODILY FORCE  Thursday
# 4   140608681  OTHER OFFENSES  VIOLATION OF MUNICIPAL CODE  Thursday
#
#          Date   Time PdDistrict      Resolution                      Address  \
# 0  05/29/2015  16:42   SOUTHERN  ARREST, BOOKED           BRYANT ST / 8TH ST
# 1  06/14/2016  08:55    BAYVIEW            NONE         1200 Block of 3RD ST
# 2  05/16/2016  00:41  INGLESIDE            NONE   WOOLSEY ST / UNIVERSITY ST
# 3  06/16/2016  21:00   SOUTHERN  ARREST, BOOKED  0 Block of UNITEDNATIONS PZ
# 4  06/16/2016  21:00   SOUTHERN  ARREST, BOOKED  0 Block of UNITEDNATIONS PZ
#
#             X          Y                               Location  \
# 0 -122.406971  37.772527  (37.7725273607571, -122.406970988225)
# 1 -122.389518  37.772468  (37.7724682400061, -122.389517648036)
# 2 -122.412470  37.722659  (37.7226585129212, -122.412469643631)
# 3 -122.414318  37.779944  (37.7799444052046, -122.414317857881)
# 4 -122.414318  37.779944  (37.7799444052046, -122.414317857881)
#
#              PdId
# 0  11091456563010
# 1   1135121075000
# 2  12078998875000
# 3  14060868103074
# 4  14060868130200

# %%
crimes_sf.Category.value_counts()
# Out:
# LARCENY/THEFT                  400224
# OTHER OFFENSES                 276609
# NON-CRIMINAL                   207987
# ASSAULT                        170313
# VEHICLE THEFT                  116480
# DRUG/NARCOTIC                  113099
# VANDALISM                       99417
# WARRANTS                        92224
# BURGLARY                        81024
# SUSPICIOUS OCC                  69855
# MISSING PERSON                  57243
# ROBBERY                         49960
# FRAUD                           36970
# SECONDARY CODES                 22271
# FORGERY/COUNTERFEITING          22055
# WEAPON LAWS                     19155
# TRESPASS                        16483
# PROSTITUTION                    15839
# STOLEN PROPERTY                 10437
# SEX OFFENSES, FORCIBLE           9912
# DISORDERLY CONDUCT               9211
# DRUNKENNESS                      9207
# RECOVERED VEHICLE                7690
# DRIVING UNDER THE INFLUENCE      5093
# KIDNAPPING                       4946
# RUNAWAY                          4047
# LIQUOR LAWS                      3930
# ARSON                            3395
# EMBEZZLEMENT                     2648
# LOITERING                        2372
# SUICIDE                          1152
# FAMILY OFFENSES                  1109
# BAD CHECKS                        872
# BRIBERY                           702
# EXTORTION                         633
# SEX OFFENSES, NON FORCIBLE        353
# GAMBLING                          318
# PORNOGRAPHY/OBSCENE MAT            48
# TREA                               11
# Name: Category, dtype: int64

# %% [markdown]
# ### Other possible SF city datasets
#
# Some other datasets may be useful for some of this project, but I'm not entirely sure if they are useful at this point in time. I will load them into the notebook to evaluate.

# %% [markdown]
# #### Zillow property sales
#
# Zillow has its own API that could provide a wealth of information - I need to dig deeper into that later. For now, here is the Zillow dataset provided that describes median sale prices ***per square foot*** for homes across the country.

# %%
zillow_median_sale = pd.read_csv('../project_data/sf_city_data/zillow_property_sales/zillow_mediansale_persqft_neighborhood.csv')

# %%
print zillow_median_sale.shape
zillow_median_sale.head()
# Out:
# (4238, 250)
#    RegionID        RegionName         City State  \
# 0    274772  Northeast Dallas       Dallas    TX
# 1    192689          Paradise    Las Vegas    NV
# 2    112345          Maryvale      Phoenix    AZ
# 3    270958   Upper West Side     New York    NY
# 4     27080      Sherman Oaks  Los Angeles    CA
#
#                             Metro   CountyName  SizeRank   1996-04   1996-05  \
# 0               Dallas-Fort Worth       Dallas         1       NaN       NaN
# 1                       Las Vegas        Clark         2   71.7410   71.7994
# 2                         Phoenix     Maricopa         3   46.6023   47.1911
# 3                        New York     New York         4  267.2269  284.3680
# 4  Los Angeles-Long Beach-Anaheim  Los Angeles         5  105.4025  102.1831
#
#     1996-06    ...        2015-09    2015-10    2015-11    2015-12    2016-01  \
# 0       NaN    ...       157.5133   151.1346   148.4390   154.5512   151.9219
# 1   70.7296    ...       119.4710   119.0146   116.6964   114.6923   113.0189
# 2   47.1452    ...        90.0998    91.9159    93.4707    95.0144    94.9214
# 3  282.8276    ...      1412.9753  1399.5488  1392.7152  1492.7994  1536.2801
# 4   99.7840    ...       421.2244   425.3723   423.0285   415.3199   411.3433
#
#      2016-02    2016-03    2016-04    2016-05    2016-06
# 0   158.5226   165.6903   170.1752   176.2920   180.1894
# 1   113.8884   114.8041   116.3150   118.9096        NaN
# 2    95.2213    96.8052    97.2812    98.3929   100.1619
# 3  1462.3706  1458.9674  1426.4533  1485.8095  1480.3050
# 4   451.6802   472.8199   492.2803   494.7221   509.6003
#
# [5 rows x 250 columns]

# %%
zillow_median_sale[zillow_median_sale.CountyName == 'San Francisco'].head()
# Out:
#      RegionID        RegionName           City State          Metro  \
# 113    274552           Mission  San Francisco    CA  San Francisco
# 340    268020    Bernal Heights  San Francisco    CA  San Francisco
# 403    117654  Central Richmond  San Francisco    CA  San Francisco
# 414    268150         Excelsior  San Francisco    CA  San Francisco
# 472    272885           Bayview  San Francisco    CA  San Francisco
#
#         CountyName  SizeRank   1996-04   1996-05   1996-06    ...      \
# 113  San Francisco       114       NaN  165.0000  174.2246    ...
# 340  San Francisco       341  199.9639  197.9637  190.1546    ...
# 403  San Francisco       404       NaN       NaN       NaN    ...
# 414  San Francisco       415  166.5026  168.5534  165.7665    ...
# 472  San Francisco       473       NaN   97.7762       NaN    ...
#
#       2015-09    2015-10   2015-11    2015-12   2016-01  2016-02   2016-03  \
# 113  992.9989  1007.8958  979.4455  1005.1700  1009.133      NaN  949.5807
# 340  950.6946  1046.6708       NaN   953.7609       NaN      NaN       NaN
# 403       NaN        NaN       NaN        NaN       NaN      NaN       NaN
# 414       NaN        NaN       NaN        NaN       NaN      NaN       NaN
# 472       NaN        NaN       NaN        NaN       NaN      NaN       NaN
#
#        2016-04      2016-05    2016-06
# 113   972.4858  1037.102300        NaN
# 340  1000.0000  1097.479000  1069.1111
# 403        NaN          NaN        NaN
# 414        NaN   733.333333        NaN
# 472        NaN   583.533173        NaN
#
# [5 rows x 250 columns]

# %% [markdown]
# #### Assesor office data
#
# Assessor data from SF City that provides information on property and sales over a ? time. Might not be super useful given the other information available, but but might provide some additional features.

# %%
# I'm going to load just the most recent data for now
sf_assessor = pd.read_csv('../project_data/sf_city_data/assessor_office/assessor_data_2014_2015.csv')
# Out:
# /Users/taylorkilian/anaconda3/envs/dsi/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (4,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print sf_assessor.shape
sf_assessor.head().T
# Out:
# (206816, 41)
#                                                0  \
# PROPLOC     0000 0000                       0000
# RP1NBRCDE                                    08H
# RP1PRCLID                               0001 001
# BASELOT                                        0
# BASELOTSFX                                   NaN
# RP1VOLUME                                      1
# RP1CLACDE                                      G
# YRBLT                                       1900
# BATHS                                          0
# BEDS                                           0
# ROOMS                                          0
# STOREYNO                                       0
# UNITS                                          0
# CHGDATE                                     9908
# REMARKFLA                                    NaN
# KITCHEN                                      NaN
# BUILTIN                                        0
# ZONE                                           P
# CONSTTYPE                                    NaN
# DEPTH                                          0
# FRONT                                          0
# SQFT                                           0
# FBA                                            0
# LAREA                                      27965
# LOTCODE                                      NaN
# REPRISDATE                                   NaN
# RP1RECDAT1                                970216
# RP1DOCNO1                                    NaN
# RP1DOCNO2                                      0
# RP1TRACDE                                   1000
# OWNRPRCNT                                      1
# EXEMPTYPE                                    NaN
# RP1STACDE                                      N
# RP1EXMVL2                                      0
# RP1EXMVL1                                      0
# ROLLYEAR                                      14
# RECURRSALD                                     0
# RP1FXTVAL                                      0
# RP1IMPVAL                                      0
# RP1LNDVAL                                      0
# RP1PPTVAL                                      0
#
#                                                1  \
# PROPLOC     0000 0000                       0000
# RP1NBRCDE                                    08H
# RP1PRCLID                               0002 001
# BASELOT                                        0
# BASELOTSFX                                   NaN
# RP1VOLUME                                      1
# RP1CLACDE                                      G
# YRBLT                                       1900
# BATHS                                          0
# BEDS                                           0
# ROOMS                                          0
# STOREYNO                                       0
# UNITS                                          0
# CHGDATE                                     9908
# REMARKFLA                                    NaN
# KITCHEN                                      NaN
# BUILTIN                                        0
# ZONE                                          C2
# CONSTTYPE                                    NaN
# DEPTH                                          0
# FRONT                                          0
# SQFT                                           0
# FBA                                            0
# LAREA                                       8359
# LOTCODE                                      NaN
# REPRISDATE                                   NaN
# RP1RECDAT1                                690229
# RP1DOCNO1                                    NaN
# RP1DOCNO2                                      0
# RP1TRACDE                                   1000
# OWNRPRCNT                                      1
# EXEMPTYPE                                    NaN
# RP1STACDE                                      N
# RP1EXMVL2                                      0
# RP1EXMVL1                                      0
# ROLLYEAR                                      14
# RECURRSALD                                     0
# RP1FXTVAL                                      0
# RP1IMPVAL                                      0
# RP1LNDVAL                                      0
# RP1PPTVAL                                      0
#
#                                                2  \
# PROPLOC     0000 0000                       0000
# RP1NBRCDE                                    08H
# RP1PRCLID                               0004 002
# BASELOT                                        0
# BASELOTSFX                                   NaN
# RP1VOLUME                                      1
# RP1CLACDE                                    VCI
# YRBLT                                          0
# BATHS                                          0
# BEDS                                           0
# ROOMS                                          0
# STOREYNO                                       0
# UNITS                                          0
# CHGDATE                                     9908
# REMARKFLA                                    NaN
# KITCHEN                                      NaN
# BUILTIN                                        0
# ZONE                                          C2
# CONSTTYPE                                    NaN
# DEPTH                                          0
# FRONT                                          0
# SQFT                                           0
# FBA                                            0
# LAREA                                          0
# LOTCODE                                      NaN
# REPRISDATE                                   NaN
# RP1RECDAT1                                791115
# RP1DOCNO1                                    NaN
# RP1DOCNO2                                      0
# RP1TRACDE                                   1000
# OWNRPRCNT                                      1
# EXEMPTYPE                                    NaN
# RP1STACDE                                      N
# RP1EXMVL2                                      0
# RP1EXMVL1                                      0
# ROLLYEAR                                      14
# RECURRSALD                                     0
# RP1FXTVAL                                      0
# RP1IMPVAL                                      0
# RP1LNDVAL                                      0
# RP1PPTVAL                                      0
#
#                                                3  \
# PROPLOC     0000 0000                       0000
# RP1NBRCDE                                    08H
# RP1PRCLID                               0005 001
# BASELOT                                        0
# BASELOTSFX                                   NaN
# RP1VOLUME                                      1
# RP1CLACDE                                      G
# YRBLT                                       1900
# BATHS                                          0
# BEDS                                           0
# ROOMS                                          0
# STOREYNO                                       0
# UNITS                                          0
# CHGDATE                                     9908
# REMARKFLA                                    NaN
# KITCHEN                                      NaN
# BUILTIN                                        0
# ZONE                                          C2
# CONSTTYPE                                    NaN
# DEPTH                                          0
# FRONT                                          0
# SQFT                                           0
# FBA                                            0
# LAREA                                      68153
# LOTCODE                                      NaN
# REPRISDATE                                   NaN
# RP1RECDAT1                                690229
# RP1DOCNO1                                    NaN
# RP1DOCNO2                                      0
# RP1TRACDE                                   1000
# OWNRPRCNT                                      1
# EXEMPTYPE                                    NaN
# RP1STACDE                                      N
# RP1EXMVL2                                      0
# RP1EXMVL1                                      0
# ROLLYEAR                                      14
# RECURRSALD                                     0
# RP1FXTVAL                                      0
# RP1IMPVAL                                      0
# RP1LNDVAL                                      0
# RP1PPTVAL                                      0
#
#                                                4
# PROPLOC     0000 0000                       0000
# RP1NBRCDE                                    08H
# RP1PRCLID                               0006 001
# BASELOT                                        0
# BASELOTSFX                                   NaN
# RP1VOLUME                                      1
# RP1CLACDE                                      G
# YRBLT                                       1900
# BATHS                                          0
# BEDS                                           0
# ROOMS                                          0
# STOREYNO                                       0
# UNITS                                          0
# CHGDATE                                     9908
# REMARKFLA                                    NaN
# KITCHEN                                      NaN
# BUILTIN                                        0
# ZONE                                          C2
# CONSTTYPE                                    NaN
# DEPTH                                          0
# FRONT                                          0
# SQFT                                           0
# FBA                                            0
# LAREA                                     108015
# LOTCODE                                      NaN
# REPRISDATE                                   NaN
# RP1RECDAT1                                690229
# RP1DOCNO1                                    NaN
# RP1DOCNO2                                      0
# RP1TRACDE                                   1000
# OWNRPRCNT                                      1
# EXEMPTYPE                                    NaN
# RP1STACDE                                      N
# RP1EXMVL2                                      0
# RP1EXMVL1                                      0
# ROLLYEAR                                      14
# RECURRSALD                                     0
# RP1FXTVAL                                      0
# RP1IMPVAL                                      0
# RP1LNDVAL                                      0
# RP1PPTVAL                                      0

# %% [markdown]
# ## Yelp info
#
# An overview of the data that can be obtained through the Yelp API.

# %% [markdown]
# Yelp Business API feature info:

# %% [markdown]
# | Name | Type | Description |
# |-----|------|------------|
# |id | string | Yelp ID of this business.|
# |name | string | Name of this business.|
# |image_url | string | URL of photo for this business.|
# |is_claimed | bool | Whether business has been claimed by a business owner|
# |is_closed | bool | Whether business has been (permanently) closed|
# |url | string | URL for business page on Yelp.|
# |price | string | Price level of the business. Value is one of $, $$, $$$ and $$$$.|
# |phone | string | Phone number of the business.|
# |rating | decimal | Rating for this business (value ranges from 1, 1.5, ... 4.5, 5).|
# |review_count | int | Number of reviews for this business.|
# |photos | object[] | URLs of up to three photos of the business.|
# |hours | object[] | Opening hours of the business.|
# |hours[x].is_open_now | boolean | Whether the business is currently open or not.|
# |hours[x].hours_type | string | The type of the opening hours information. Right now, always return REGULAR.|
# |hours[x].open | object[] | The detailed opening hours of each day in a week.|
# |hours[x].open[x].day | int | From 0 to 6, representing day of the week from Monday to Sunday. Notice that you may get the same day of the week more than once if the business has more than one opening time slots.|
# |hours[x].open[x].start | string | Start of the opening hours in a day, in 24-hour clock notation, like 1000 means 10 AM.|
# |hours[x].open[x].start | string | Start of the opening hours in a day, in 24-hour clock notation, like 1000 means 10 AM.|
# |hours[x].open[x].end | string | End of the opening hours in a day, in 24-hour clock notation, like 2130 means 9:30 PM.|
# |hours[x].open[x].is_overnight | boolean | Whether the business opens overnight or not. When this is true, the end time will be lower than the start time.|
# |categories | object[] | A list of category title and alias pairs associated with this business.|
# |categories[x].alias | string | Alias of a category, when searching for business in certain categories, use alias rather than the title.|
# |categories[x].title | string | Title of a category for display purpose.|
# |coordinates | object | The coordinates of this business.|
# |coordinates.latitude | decimal | The latitude of this business.|
# |coordinates.longitude | decimal | The longitude of this business.|
# |location | object | The location of this business, including address, city, state, zip code and country.|
# |location.address1 | string | Street address of this business.|
# |location.address2 | string | Street address of this business, continued.|
# |location.address3 | string | Street address of this business, continued.|
# |location.city | string | City of this business.|
# |location.state | string | ISO 3166-2 State code of this business.|
# |location.zip_code | string | Zip code of this business.|
# |location.country | string | ISO 3166-1 alpha-2 country code of this business.|
# |location.cross_streets | string | Cross streets for this business.|
# |transactions | string[] | A list of Yelp transactions that the business is registered for. Current supported values are "pickup", "delivery", and "restaurant_reservation".|

# %% [markdown]
# Yelp reviews API only returns three reviews per business and requires that the individual business id be placed into the GET request url.

# %% [markdown]
# |Name | Type | Description|
# |-----|------|------------|
# |total | int | The total number of reviews that the business has.|
# |reviews | object[] | A list of up to three reviews of this business.|
# |reviews[x].text | string | Text excerpt of this review.|
# |reviews[x].url | string | URL of this review.|
# |reviews[x].rating | int | Rating of this review.|
# |reviews[x].time_created | string | The time that the review was created in PST.|
# |reviews[x].user | object | The user who wrote the review.|
# |reviews[x].user.name | string | Name of the user.|
# |reviews[x].user.image_url | string | URL of the user's profile photo.|

# %% [markdown]
# ## Airbnb preliminary data treatment
#
# The goal is to clean the Airbnb datasets then combine the calendar df (which includes prices) with the listings df and the reviews df. This combined Airbnb dataset will then be used to build, train, and test a preliminary pricing model for rentals.
#
# Much of the data still need to be converted to numeric types. Need to also check if all listing ids match across the various tables. Would be great to do some NLP on the reviews and maybe listing info. I am assuming that the listing info provided by owners is going to be from a rose-colored glasses perspective, but might still be useful.
#
# There is a lot of other information that could be combined with this to make a more robust model, but it will be good to establish a baseline first. Also, there are still somethings that need to be hammered out, like how the prices could changes depending on the date of the rental - for now I may just assign a rental rate that is the mean of all of the prices through the year (i.e. not just a mean of the high and low price but a mean over all of the days the listing is available for rent).

# %%
print 'Number or listings ids in "calendar": {}'.format(len(bnb_cal.listing_id.unique()))
print 'Number or listings ids in "listings": {}'.format(len(bnb_listings.id.unique()))
print 'Number or listings ids in "reviews": {}'.format(len(bnb_reviews.listing_id.unique()))
# Out:
# Number or listings ids in "calendar": 8619
# Number or listings ids in "listings": 8619
# Number or listings ids in "reviews": 6396

# %% [markdown]
# It appears that there are not reviews for every listing, this could be because some of them are new listings or people signed up but never actually listed their units. For most of the listings there are many reviews that need to be coalesced for word analysis. Listings that are missing reviews may have never had guests, for one reason or another.

# %%
bnb_reviews[bnb_reviews.listing_id == 3320213]
# Out:
#     listing_id        id        date  reviewer_id      reviewer_name  \
# 1      3320213  14805088  2014-06-26     17101713               Faye
# 2      3320213  17192435  2014-08-08       182792  Jocelyne & Pontus
# 3      3320213  17597907  2014-08-14     19649465          Francesco
# 4      3320213  18293826  2014-08-24      1104165             Daniel
# 5      3320213  18602107  2014-08-28     20421291             Dervla
# 6      3320213  18962894  2014-09-03      5356869               Lily
# 7      3320213  19856731  2014-09-19      4522712                Eli
# 8      3320213  20627838  2014-10-02     21535655             Sergiu
# 9      3320213  20802533  2014-10-05     21988006            Kenneth
# 10     3320213  21475691  2014-10-18     21643735             Joanna
# 11     3320213  23934713  2014-12-14     24770822             Hayley
# 12     3320213  24214582  2014-12-22     24971944               Dash
# 13     3320213  24350459  2014-12-26     14470174             Smitha
# 14     3320213  24690878  2015-01-01     25140184            Madelin
# 15     3320213  26577293  2015-02-15     26226029             George
# 16     3320213  27973730  2015-03-15     29050391              Wadih
# 17     3320213  28640830  2015-03-27     11465559              Diana
# 18     3320213  29079110  2015-04-03      2771864             Daniel
# 19     3320213  29573423  2015-04-09      3202389              Aaron
# 20     3320213  29706726  2015-04-11     30601639              Leroy
# 21     3320213  29956701  2015-04-14     30944414               Leah
# 22     3320213  30338006  2015-04-20     28559961               Kate
# 23     3320213  32008819  2015-05-12      8946146              Katie
# 24     3320213  32192410  2015-05-15     16307004             Collin
# 25     3320213  33053535  2015-05-24      3121482                Les
# 26     3320213  33412618  2015-05-27       510171              Reema
# 27     3320213  36354263  2015-06-27      6836324              Pilar
# 28     3320213  36404148  2015-06-28     13065529                 Mo
# 29     3320213  50370405  2015-10-11     45328245             Cyntia
#
#                                              comments
# 1   The place was clean and spacious and the guy t...
# 2   This place wasn't as pleasant as we hoped. Had...
# 3   Si tratta di una piccola pensione/albergo.\nSt...
# 4   Nice room, cool neighbourhood. Note that this ...
# 5   The listing was accurate and the location was ...
# 6                                     Great location!
# 7   There is very little host interaction since yo...
# 8   Very good place. It is very clean and quiet. I...
# 9   Great location, comfy room. Accommodating host...
# 10  Note that this room is in an actual hotel. It ...
# 11  Great location. There are a lot of good places...
# 12                     Nice place, cool part of town
# 13                            Comfy, worth the price!
# 14  Room was in a hotel, small rooms with Hawaiian...
# 15  Great place. Located centrally in the Mission....
# 16  Stayed there with a couple of friends.\nThe ho...
# 17  It's a walk up so if you have a ton of luggage...
# 18  Great stay with a central location. The room w...
# 19  This location is fantastic. It's basically a H...
# 20  The hotel is located on a medium busy street w...
# 21  The room is actually in a hotel, which is not ...
# 22  Great value for San Francisco! The rooms were ...
# 23  Great location, clean, safe, and affordable. O...
# 24                     It was clean. Great location.
# 25  Unfortunately we did not get a chance to stay ...
# 26  It's not the best motel in town.  Smelled like...
# 27                LOCATION, LOCARION, LOCATION!!! : )
# 28  Two of my friends got rash from sitting on the...
# 29  I tried to confirm my stay multiple times, mad...

# %% [markdown]
# First, I need to deal with the prices from the calendar table, which need to be grouped by id, aggregating the prices by taking the mean for each listing. The listings summary table actually has pricing information for each listing but I want to see if those prices are consistent and take into account the vairable rate that some people charge for their rentals.

# %%
bnb_listings_sum.id.unique().shape
# Out:
# (8619,)

# %%
cal_mean_prices = bnb_cal.groupby("listing_id")[["price"]].mean()
cal_mean_prices.reset_index(inplace=True)
cal_mean_prices.tail()
# Out:
#       listing_id      price
# 8614    13801466  55.000000
# 8615    13802849  61.071429
# 8616    13802856  75.000000
# 8617    13803228        NaN
# 8618    13803588  60.000000

# %%
bnb_listings_sum[bnb_listings_sum.id == 13803228]
# Out:
#             id                          name   host_id host_name  \
# 1037  13803228  Fab Mid-Century Master Suite  79745762      Troy
#
#       neighbourhood_group    neighbourhood   latitude   longitude  \
# 1037                  NaN  Diamond Heights  37.746253 -122.444623
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 1037  Private room    195               2                  0         NaN
#
#       reviews_per_month  calculated_host_listings_count  availability_365
# 1037                NaN                               1                 0

# %% [markdown]
# Some of the units that don't have any prices listed in the calendar have prices given in the listings summary table. Need to decide what to do about this - it's pretty clear that people may have stopped making their units available for rent (missing from calendar availibility) even though they still have a rental profile/summary available in the listings summary table.

# %%
bnb_listings.T
# Out:
#                                                                                0     \
# id                                                                         11187767
# listing_url                                   https://www.airbnb.com/rooms/11187767
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                             Huge Seacliff Penthouse With Views
# summary                           Amazing views from this immense 3 bedroom/ 2 b...
# space                             Spacious patio deck, library with over 300 mov...
# description                       Amazing views from this immense 3 bedroom/ 2 b...
# experiences_offered                                                            none
# neighborhood_overview             The neighborhood includes Legion of Honor, Sut...
# notes                             We require a separate rental agreement to be s...
# transit                           Public Transportation including Muni and the B...
# access                            Guests have access to the entire flat includin...
# interaction                         I am available 24 hours a day during your stay.
# house_rules                       1. Smoking is NOT allowed in the Property, Com...
# thumbnail_url                     https://a2.muscache.com/im/pictures/e8652800-a...
# medium_url                        https://a2.muscache.com/im/pictures/e8652800-a...
# picture_url                       https://a2.muscache.com/im/pictures/e8652800-a...
# xl_picture_url                    https://a2.muscache.com/im/pictures/e8652800-a...
# host_id                                                                    58242037
# host_url                                 https://www.airbnb.com/users/show/58242037
# host_name                                                                  Jonathan
# host_since                                                               2016-02-10
# host_location                              San Francisco, California, United States
# host_about                        Property Manager for Watt Property Management,...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                           100%
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a2.muscache.com/im/pictures/351d2fbc-4...
# ...                                                                             ...
# guests_included                                                                   1
# extra_people                                                                  $0.00
# minimum_nights                                                                    2
# maximum_nights                                                                   28
# calendar_updated                                                              today
# has_availability                                                                NaN
# availability_30                                                                   8
# availability_60                                                                  31
# availability_90                                                                  61
# availability_365                                                                152
# calendar_last_scraped                                                    2016-07-02
# number_of_reviews                                                                 3
# first_review                                                             2016-03-23
# last_review                                                              2016-06-25
# review_scores_rating                                                             80
# review_scores_accuracy                                                            9
# review_scores_cleanliness                                                         9
# review_scores_checkin                                                             9
# review_scores_communication                                                       9
# review_scores_location                                                            9
# review_scores_value                                                               8
# requires_license                                                                  t
# license                                                                         NaN
# jurisdiction_names                                                    SAN FRANCISCO
# instant_bookable                                                                  t
# cancellation_policy                                                          strict
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    1
# reviews_per_month                                                              0.88
#
#                                                                                1     \
# id                                                                          6938818
# listing_url                                    https://www.airbnb.com/rooms/6938818
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                                            Best Secret in Town
# summary                           My two story house is located in the quite sid...
# space                             The room is spacious and it is on the top leve...
# description                       My two story house is located in the quite sid...
# experiences_offered                                                            none
# neighborhood_overview             It is in the city and close to everything. Par...
# notes                             The summer in San Francisco is cooler than any...
# transit                           If you are on budget, the public transportatio...
# access                            You will have full access to your room, bathro...
# interaction                       I may not available in person to assist you du...
# house_rules                       1.  No pets, no smoking inside the house. 2. F...
# thumbnail_url                     https://a2.muscache.com/im/pictures/441473b8-6...
# medium_url                        https://a2.muscache.com/im/pictures/441473b8-6...
# picture_url                       https://a2.muscache.com/im/pictures/441473b8-6...
# xl_picture_url                    https://a2.muscache.com/im/pictures/441473b8-6...
# host_id                                                                    36381578
# host_url                                 https://www.airbnb.com/users/show/36381578
# host_name                                                                    Harris
# host_since                                                               2015-06-21
# host_location                              San Francisco, California, United States
# host_about                        Retired Accounting Professional. Down to earth...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                           100%
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a2.muscache.com/im/pictures/a3435acf-3...
# ...                                                                             ...
# guests_included                                                                   2
# extra_people                                                                 $20.00
# minimum_nights                                                                    3
# maximum_nights                                                                   30
# calendar_updated                                                        2 weeks ago
# has_availability                                                                NaN
# availability_30                                                                   2
# availability_60                                                                   7
# availability_90                                                                   8
# availability_365                                                                187
# calendar_last_scraped                                                    2016-07-02
# number_of_reviews                                                                23
# first_review                                                             2015-06-27
# last_review                                                              2016-06-16
# review_scores_rating                                                             91
# review_scores_accuracy                                                            9
# review_scores_cleanliness                                                         9
# review_scores_checkin                                                            10
# review_scores_communication                                                      10
# review_scores_location                                                            9
# review_scores_value                                                               9
# requires_license                                                                  t
# license                           S. F. Short-Term Residential Rental Registrati...
# jurisdiction_names                                                    SAN FRANCISCO
# instant_bookable                                                                  f
# cancellation_policy                                                          strict
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    2
# reviews_per_month                                                              1.85
#
#                                                                                2     \
# id                                                                          9395222
# listing_url                                    https://www.airbnb.com/rooms/9395222
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                                  Ocean Beach, Lands End Escape
# summary                           Come relax in our 1 bedroom 1 bath house minut...
# space                             Huge backyard with a FirePit and lounge chairs...
# description                       Come relax in our 1 bedroom 1 bath house minut...
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                                                                           NaN
# transit                           38 Geary stop is 1 block away that will take y...
# access                            Entire 1 bedroom 1 bath, huge backyard and a p...
# interaction                                                                     NaN
# house_rules                       *No smoking please *QUITE HOURS 10pm-9am pleas...
# thumbnail_url                     https://a2.muscache.com/im/pictures/103e2c9f-2...
# medium_url                        https://a2.muscache.com/im/pictures/103e2c9f-2...
# picture_url                       https://a2.muscache.com/im/pictures/103e2c9f-2...
# xl_picture_url                    https://a2.muscache.com/im/pictures/103e2c9f-2...
# host_id                                                                    25963295
# host_url                                 https://www.airbnb.com/users/show/25963295
# host_name                                                                     Tyler
# host_since                                                               2015-01-11
# host_location                              San Francisco, California, United States
# host_about                        My husband and I go back and forth between San...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                            99%
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a2.muscache.com/im/pictures/bf8a0d2e-7...
# ...                                                                             ...
# guests_included                                                                   2
# extra_people                                                                 $10.00
# minimum_nights                                                                    1
# maximum_nights                                                                 1125
# calendar_updated                                                         5 days ago
# has_availability                                                                NaN
# availability_30                                                                   0
# availability_60                                                                   6
# availability_90                                                                  20
# availability_365                                                                167
# calendar_last_scraped                                                    2016-07-02
# number_of_reviews                                                                45
# first_review                                                             2015-11-16
# last_review                                                              2016-06-19
# review_scores_rating                                                             88
# review_scores_accuracy                                                            9
# review_scores_cleanliness                                                         9
# review_scores_checkin                                                            10
# review_scores_communication                                                      10
# review_scores_location                                                           10
# review_scores_value                                                               9
# requires_license                                                                  t
# license                                                                         NaN
# jurisdiction_names                                                    SAN FRANCISCO
# instant_bookable                                                                  t
# cancellation_policy                                                          strict
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    1
# reviews_per_month                                                              5.87
#
#                                                                                3     \
# id                                                                          8388658
# listing_url                                    https://www.airbnb.com/rooms/8388658
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                            Mid-century Seacliff near GG Bridge
# summary                           Three-bedroom in exclusive Seacliff neighborho...
# space                                                                           NaN
# description                       Three-bedroom in exclusive Seacliff neighborho...
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                                                                           NaN
# transit                                                                         NaN
# access                                                                          NaN
# interaction                                                                     NaN
# house_rules                                                                     NaN
# thumbnail_url                     https://a1.muscache.com/im/pictures/106926931/...
# medium_url                        https://a1.muscache.com/im/pictures/106926931/...
# picture_url                       https://a1.muscache.com/im/pictures/106926931/...
# xl_picture_url                    https://a1.muscache.com/im/pictures/106926931/...
# host_id                                                                     9996441
# host_url                                  https://www.airbnb.com/users/show/9996441
# host_name                                                                    Howard
# host_since                                                               2013-11-13
# host_location                              San Francisco, California, United States
# host_about                        We are a family of four, all avid travelers.  ...
# host_response_time                                                              NaN
# host_response_rate                                                              NaN
# host_acceptance_rate                                                            NaN
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a0.muscache.com/im/users/9996441/profi...
# ...                                                                             ...
# guests_included                                                                   1
# extra_people                                                                  $0.00
# minimum_nights                                                                    3
# maximum_nights                                                                   14
# calendar_updated                                                       6 months ago
# has_availability                                                                NaN
# availability_30                                                                   0
# availability_60                                                                   0
# availability_90                                                                   0
# availability_365                                                                  0
# calendar_last_scraped                                                    2016-07-02
# number_of_reviews                                                                 0
# first_review                                                                    NaN
# last_review                                                                     NaN
# review_scores_rating                                                            NaN
# review_scores_accuracy                                                          NaN
# review_scores_cleanliness                                                       NaN
# review_scores_checkin                                                           NaN
# review_scores_communication                                                     NaN
# review_scores_location                                                          NaN
# review_scores_value                                                             NaN
# requires_license                                                                  t
# license                                                                         NaN
# jurisdiction_names                                                    SAN FRANCISCO
# instant_bookable                                                                  f
# cancellation_policy                                                        flexible
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    1
# reviews_per_month                                                               NaN
#
#                                                                                4     \
# id                                                                          7856443
# listing_url                                    https://www.airbnb.com/rooms/7856443
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                                      The Real San Francisco #2
# summary                           Minutes to GG Bridge, GG Park, Museums, The Pr...
# space                             Following the wild popularity of our downstair...
# description                       Minutes to GG Bridge, GG Park, Museums, The Pr...
# experiences_offered                                                            none
# neighborhood_overview             For those who love the outdoors and good food,...
# notes                                                                           NaN
# transit                           STREET PARKING Street parking in our neighborh...
# access                            Guests are permitted access to the entire main...
# interaction                       We'll be gone.  You'll hear some noise/talking...
# house_rules                       We have neighbors (a family) and guests (also ...
# thumbnail_url                     https://a2.muscache.com/im/pictures/6cf5a572-a...
# medium_url                        https://a2.muscache.com/im/pictures/6cf5a572-a...
# picture_url                       https://a2.muscache.com/im/pictures/6cf5a572-a...
# xl_picture_url                    https://a2.muscache.com/im/pictures/6cf5a572-a...
# host_id                                                                     6076870
# host_url                                  https://www.airbnb.com/users/show/6076870
# host_name                                                          Todd And Tatyana
# host_since                                                               2013-04-24
# host_location                              San Francisco, California, United States
# host_about                        We're backpackers at heart.  We've bagged over...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                           100%
# host_is_superhost                                                                 t
# host_thumbnail_url                https://a1.muscache.com/im/users/6076870/profi...
# ...                                                                             ...
# guests_included                                                                   1
# extra_people                                                                  $0.00
# minimum_nights                                                                    2
# maximum_nights                                                                 1125
# calendar_updated                                                         6 days ago
# has_availability                                                                NaN
# availability_30                                                                   2
# availability_60                                                                   2
# availability_90                                                                   9
# availability_365                                                                 23
# calendar_last_scraped                                                    2016-07-02
# number_of_reviews                                                                 4
# first_review                                                             2016-05-15
# last_review                                                              2016-06-22
# review_scores_rating                                                            100
# review_scores_accuracy                                                           10
# review_scores_cleanliness                                                        10
# review_scores_checkin                                                            10
# review_scores_communication                                                      10
# review_scores_location                                                           10
# review_scores_value                                                              10
# requires_license                                                                  t
# license                                                                         NaN
# jurisdiction_names                                                    SAN FRANCISCO
# instant_bookable                                                                  f
# cancellation_policy                                                          strict
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    2
# reviews_per_month                                                              2.45
#
#                                                                                5     \
# id                                                                          4781448
# listing_url                                    https://www.airbnb.com/rooms/4781448
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                            3 Bd 2.5 Ba Full Flat Condo w Views
# summary                           Our family-friendly condo is located in San Fr...
# space                             Open concept living, dining area has great cit...
# description                       Our family-friendly condo is located in San Fr...
# experiences_offered                                                            none
# neighborhood_overview             We are located across the street from Lincoln ...
# notes                             2 night minimum stay please. San Francisco Sho...
# transit                           Easy bus access to the entire city with 3 bus ...
# access                                       Guests have access to the entire home.
# interaction                       We are happy hosts to our city and can give gr...
# house_rules                       • Check-in time is 4PM. This is our home, so w...
# thumbnail_url                     https://a2.muscache.com/im/pictures/71426241/2...
# medium_url                        https://a2.muscache.com/im/pictures/71426241/2...
# picture_url                       https://a2.muscache.com/im/pictures/71426241/2...
# xl_picture_url                    https://a2.muscache.com/im/pictures/71426241/2...
# host_id                                                                    13112558
# host_url                                 https://www.airbnb.com/users/show/13112558
# host_name                                                                       Pam
# host_since                                                               2014-03-14
# host_location                              San Francisco, California, United States
# host_about                        I like experiencing the authentic culture of t...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                            95%
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a0.muscache.com/im/users/13112558/prof...
# ...                                                                             ...
# guests_included                                                                   4
# extra_people                                                                 $25.00
# minimum_nights                                                                    3
# maximum_nights                                                                   18
# calendar_updated                                                         2 days ago
# has_availability                                                                NaN
# availability_30                                                                   0
# availability_60                                                                   0
# availability_90                                                                   5
# availability_365                                                                  5
# calendar_last_scraped                                                    2016-07-02
# number_of_reviews                                                                 6
# first_review                                                             2015-08-11
# last_review                                                              2016-04-04
# review_scores_rating                                                            100
# review_scores_accuracy                                                           10
# review_scores_cleanliness                                                        10
# review_scores_checkin                                                            10
# review_scores_communication                                                      10
# review_scores_location                                                           10
# review_scores_value                                                              10
# requires_license                                                                  t
# license                           San Francisco Short-Term Residential Rental Re...
# jurisdiction_names                                                    SAN FRANCISCO
# instant_bookable                                                                  f
# cancellation_policy                                                          strict
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    1
# reviews_per_month                                                              0.55
#
#                                                                                6     \
# id                                                                          1427660
# listing_url                                    https://www.airbnb.com/rooms/1427660
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                             Charming Studio Apt at Ocean Beach
# summary                           Charming, private, peaceful hideaway 2 blocks ...
# space                             Dear Guests, This quiet and private, 1 bedroom...
# description                       Charming, private, peaceful hideaway 2 blocks ...
# experiences_offered                                                            none
# neighborhood_overview             I'm excited for you to discover why I love liv...
# notes                             The studio is not equipped for cooking, nor do...
# transit                           Public transport by bus to take you anywhere i...
# access                            Guests enter and exit the private studio via m...
# interaction                       You decide how much socialization or privacy y...
# house_rules                       Absolutely NO SMOKING or drugs on property - p...
# thumbnail_url                     https://a2.muscache.com/im/pictures/65878462/5...
# medium_url                        https://a2.muscache.com/im/pictures/65878462/5...
# picture_url                       https://a2.muscache.com/im/pictures/65878462/5...
# xl_picture_url                    https://a2.muscache.com/im/pictures/65878462/5...
# host_id                                                                     2275604
# host_url                                  https://www.airbnb.com/users/show/2275604
# host_name                                                                    Laurie
# host_since                                                               2012-05-02
# host_location                              San Francisco, California, United States
# host_about                        I LOVE San Francisco!! I mean, I am IN LOVE wi...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                           100%
# host_is_superhost                                                                 t
# host_thumbnail_url                https://a1.muscache.com/im/users/2275604/profi...
# ...                                                                             ...
# guests_included                                                                   2
# extra_people                                                                 $10.00
# minimum_nights                                                                    2
# maximum_nights                                                                    7
# calendar_updated                                                        2 weeks ago
# has_availability                                                                NaN
# availability_30                                                                   1
# availability_60                                                                   4
# availability_90                                                                   8
# availability_365                                                                259
# calendar_last_scraped                                                    2016-07-02
# number_of_reviews                                                               236
# first_review                                                             2013-08-28
# last_review                                                              2016-06-24
# review_scores_rating                                                             98
# review_scores_accuracy                                                           10
# review_scores_cleanliness                                                        10
# review_scores_checkin                                                            10
# review_scores_communication                                                      10
# review_scores_location                                                           10
# review_scores_value                                                              10
# requires_license                                                                  t
# license                                                                 STR-0000026
# jurisdiction_names                                                    SAN FRANCISCO
# instant_bookable                                                                  f
# cancellation_policy                                                        flexible
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    1
# reviews_per_month                                                              6.81
#
#                                                                                7     \
# id                                                                          8087607
# listing_url                                    https://www.airbnb.com/rooms/8087607
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                              Single Room Beautiful Beach Condo
# summary                           When I travel, my quiet beach side condo makes...
# space                                                                           NaN
# description                       When I travel, my quiet beach side condo makes...
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                                                                           NaN
# transit                                                                         NaN
# access                                                                          NaN
# interaction                                                                     NaN
# house_rules                                                                     NaN
# thumbnail_url                     https://a1.muscache.com/im/pictures/103040877/...
# medium_url                        https://a1.muscache.com/im/pictures/103040877/...
# picture_url                       https://a1.muscache.com/im/pictures/103040877/...
# xl_picture_url                    https://a1.muscache.com/im/pictures/103040877/...
# host_id                                                                     3264449
# host_url                                  https://www.airbnb.com/users/show/3264449
# host_name                                                                     Keith
# host_since                                                               2012-08-15
# host_location                                                          Tokyo, Japan
# host_about                        i'm a software engineer that works on (SENSITI...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                           100%
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a2.muscache.com/im/pictures/5b9b9ea1-0...
# ...                                                                             ...
# guests_included                                                                   1
# extra_people                                                                  $0.00
# minimum_nights                                                                    1
# maximum_nights                                                                 1125
# calendar_updated                                                      10 months ago
# has_availability                                                                NaN
# availability_30                                                                   0
# availability_60                                                                   0
# availability_90                                                                   0
# availability_365                                                                  0
# calendar_last_scraped                                                    2016-07-02
# number_of_reviews                                                                 0
# first_review                                                                    NaN
# last_review                                                                     NaN
# review_scores_rating                                                            NaN
# review_scores_accuracy                                                          NaN
# review_scores_cleanliness                                                       NaN
# review_scores_checkin                                                           NaN
# review_scores_communication                                                     NaN
# review_scores_location                                                          NaN
# review_scores_value                                                             NaN
# requires_license                                                                  t
# license                                                                         NaN
# jurisdiction_names                                                    SAN FRANCISCO
# instant_bookable                                                                  f
# cancellation_policy                                                        flexible
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    1
# reviews_per_month                                                               NaN
#
#                                                                                8     \
# id                                                                          9904485
# listing_url                                    https://www.airbnb.com/rooms/9904485
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                                                    Great Room!
# summary                                    Quite house, clean room, nice roommates.
# space                                                                           NaN
# description                                Quite house, clean room, nice roommates.
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                                                                           NaN
# transit                                                                         NaN
# access                                                                          NaN
# interaction                                                                     NaN
# house_rules                                                                     NaN
# thumbnail_url                     https://a2.muscache.com/im/pictures/49cd30d8-2...
# medium_url                        https://a2.muscache.com/im/pictures/49cd30d8-2...
# picture_url                       https://a2.muscache.com/im/pictures/49cd30d8-2...
# xl_picture_url                    https://a2.muscache.com/im/pictures/49cd30d8-2...
# host_id                                                                    13046907
# host_url                                 https://www.airbnb.com/users/show/13046907
# host_name                                                                      John
# host_since                                                               2014-03-12
# host_location                              San Francisco, California, United States
# host_about                        Hello!\r\n\r\nI am currently in grad school pu...
# host_response_time                                                              NaN
# host_response_rate                                                              NaN
# host_acceptance_rate                                                            NaN
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a0.muscache.com/im/users/13046907/prof...
# ...                                                                             ...
# guests_included                                                                   1
# extra_people                                                                  $0.00
# minimum_nights                                                                    1
# maximum_nights                                                                 1125
# calendar_updated                                                       7 months ago
# has_availability                                                                NaN
# availability_30                                                                   0
# availability_60                                                                   0
# availability_90                                                                   0
# availability_365                                                                  0
# calendar_last_scraped                                                    2016-07-02
# number_of_reviews                                                                 0
# first_review                                                                    NaN
# last_review                                                                     NaN
# review_scores_rating                                                            NaN
# review_scores_accuracy                                                          NaN
# review_scores_cleanliness                                                       NaN
# review_scores_checkin                                                           NaN
# review_scores_communication                                                     NaN
# review_scores_location                                                          NaN
# review_scores_value                                                             NaN
# requires_license                                                                  t
# license                                                                         NaN
# ...
# listing_url                                   https://www.airbnb.com/rooms/13203823
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                        Beautiful Big Boat -  Fort Mason/Marina
# summary                           Want to go for a run to the Golden Gate Bridge...
# space                             This is a very nice place to stay.  Even thoug...
# description                       Want to go for a run to the Golden Gate Bridge...
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                             If the day proves to be a sunny one, you have ...
# transit                                                                         NaN
# access                            Please think of the Boat as a hotel room with ...
# interaction                       You will be able to reach my on cell phone any...
# house_rules                       - Please respect neighbors.  This is a beautif...
# thumbnail_url                     https://a2.muscache.com/im/pictures/03e607fc-3...
# medium_url                        https://a2.muscache.com/im/pictures/03e607fc-3...
# picture_url                       https://a2.muscache.com/im/pictures/03e607fc-3...
# xl_picture_url                    https://a2.muscache.com/im/pictures/03e607fc-3...
# host_id                                                                     4408364
# host_url                                  https://www.airbnb.com/users/show/4408364
# host_name                                                                    Wesley
# host_since                                                               2012-12-15
# host_location                              San Francisco, California, United States
# host_about                                                                      NaN
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                           100%
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a2.muscache.com/im/pictures/49fb8ae0-e...
# ...                                                                             ...
# guests_included                                                                   1
# extra_people                                                                  $0.00
# minimum_nights                                                                    1
# maximum_nights                                                                    3
# calendar_updated                                                         5 days ago
# has_availability                                                                NaN
# availability_30                                                                   0
# availability_60                                                                   0
# availability_90                                                                   0
# availability_365                                                                  0
# calendar_last_scraped                                                    2016-07-02
# number_of_reviews                                                                 3
# first_review                                                             2016-06-16
# last_review                                                              2016-06-25
# review_scores_rating                                                            100
# review_scores_accuracy                                                           10
# review_scores_cleanliness                                                        10
# review_scores_checkin                                                            10
# review_scores_communication                                                      10
# review_scores_location                                                           10
# review_scores_value                                                               9
# requires_license                                                                  t
# license                                                                         NaN
# jurisdiction_names                                                    SAN FRANCISCO
# instant_bookable                                                                  f
# cancellation_policy                                                        flexible
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    1
# reviews_per_month                                                                 3
#
#                                                                                8617  \
# id                                                                         13671441
# listing_url                                   https://www.airbnb.com/rooms/13671441
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                              15 min to SF DT / Hacker House M1
# summary                           Our guests are young and smart startup founder...
# space                                                                           NaN
# description                       Our guests are young and smart startup founder...
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                                                                           NaN
# transit                                                                         NaN
# access                                                                          NaN
# interaction                                                                     NaN
# house_rules                                                                     NaN
# thumbnail_url                     https://a2.muscache.com/im/pictures/a6511356-7...
# medium_url                        https://a2.muscache.com/im/pictures/a6511356-7...
# picture_url                       https://a2.muscache.com/im/pictures/a6511356-7...
# xl_picture_url                    https://a2.muscache.com/im/pictures/a6511356-7...
# host_id                                                                     5932384
# host_url                                  https://www.airbnb.com/users/show/5932384
# host_name                                                                    Sergey
# host_since                                                               2013-04-15
# host_location                              San Francisco, California, United States
# host_about                        Hello for everyone.\r\nI am co-founder of Hack...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                            70%
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a2.muscache.com/im/pictures/34c02028-d...
# ...                                                                             ...
# guests_included                                                                   1
# extra_people                                                                 $40.00
# minimum_nights                                                                    7
# maximum_nights                                                                 1125
# calendar_updated                                                         6 days ago
# has_availability                                                                NaN
# availability_30                                                                  25
# availability_60                                                                  51
# availability_90                                                                  81
# availability_365                                                                171
# calendar_last_scraped                                                    2016-07-02
# number_of_reviews                                                                 0
# first_review                                                                    NaN
# last_review                                                                     NaN
# review_scores_rating                                                            NaN
# review_scores_accuracy                                                          NaN
# review_scores_cleanliness                                                       NaN
# review_scores_checkin                                                           NaN
# review_scores_communication                                                     NaN
# review_scores_location                                                          NaN
# review_scores_value                                                             NaN
# requires_license                                                                  f
# license                                                                         NaN
# jurisdiction_names                                                              NaN
# instant_bookable                                                                  f
# cancellation_policy                                                        moderate
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                   29
# reviews_per_month                                                               NaN
#
#                                                                                8618
# id                                                                         13714376
# listing_url                                   https://www.airbnb.com/rooms/13714376
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                              15 min to SF DT / Hacker House M5
# summary                           My place is close to Bart station . You’ll lov...
# space                                                                           NaN
# description                       My place is close to Bart station . You’ll lov...
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                                                                           NaN
# transit                                                                         NaN
# access                                                                          NaN
# interaction                                                                     NaN
# house_rules                                                                     NaN
# thumbnail_url                     https://a2.muscache.com/im/pictures/196267ee-1...
# medium_url                        https://a2.muscache.com/im/pictures/196267ee-1...
# picture_url                       https://a2.muscache.com/im/pictures/196267ee-1...
# xl_picture_url                    https://a2.muscache.com/im/pictures/196267ee-1...
# host_id                                                                     5932384
# host_url                                  https://www.airbnb.com/users/show/5932384
# host_name                                                                    Sergey
# host_since                                                               2013-04-15
# host_location                              San Francisco, California, United States
# host_about                        Hello for everyone.\r\nI am co-founder of Hack...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                            70%
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a2.muscache.com/im/pictures/34c02028-d...
# ...                                                                             ...
# guests_included                                                                   1
# extra_people                                                                 $40.00
# minimum_nights                                                                    2
# maximum_nights                                                                 1125
# calendar_updated                                                         6 days ago
# has_availability                                                                NaN
# availability_30                                                                  26
# availability_60                                                                  56
# availability_90                                                                  86
# availability_365                                                                 86
# calendar_last_scraped                                                    2016-07-02
# number_of_reviews                                                                 0
# first_review                                                                    NaN
# last_review                                                                     NaN
# review_scores_rating                                                            NaN
# review_scores_accuracy                                                          NaN
# review_scores_cleanliness                                                       NaN
# review_scores_checkin                                                           NaN
# review_scores_communication                                                     NaN
# review_scores_location                                                          NaN
# review_scores_value                                                             NaN
# requires_license                                                                  f
# license                                                                         NaN
# jurisdiction_names                                                              NaN
# instant_bookable                                                                  f
# cancellation_policy                                                        moderate
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                   29
# reviews_per_month                                                               NaN
#
# [95 rows x 8619 columns]

# %%
listing_cols = bnb_listings.columns.values

# %%
bnb_listings.room_type[1000]
# Out:
# 'Private room'

# %% [markdown]
# Merge summary table with the prices calculated from the calendar table.

# %%
cal_sum.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            2
# neighbourhood_group               8619
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price_x                              0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       2223
# reviews_per_month                 2223
# calculated_host_listings_count       0
# availability_365                     0
# listing_id                           0
# price_y                           2227
# price_mod                            0
# dtype: int64

# %%
cal_sum = bnb_listings_sum.merge(cal_mean_prices, left_on="id", right_on="listing_id", how='left')
cal_sum['price_mod'] = cal_sum.price_y.values
cal_sum.price_mod.fillna(cal_sum['price_x'], inplace=True)
price_cut = cal_sum[['id', 'price_y', 'price_mod']]
cal_sum.head(1)
# Out:
#          id                                name   host_id host_name  \
# 0  11187767  Huge Seacliff Penthouse With Views  58242037  Jonathan
#
#    neighbourhood_group neighbourhood   latitude   longitude        room_type  \
# 0                  NaN      Seacliff  37.779685 -122.510472  Entire home/apt
#
#    price_x  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0      400               2                  3  2016-06-25               0.88
#
#    calculated_host_listings_count  availability_365  listing_id     price_y  \
# 0                               1               152    11187767  497.368421
#
#     price_mod
# 0  497.368421

# %% [markdown]
# Almost all of the columns from the summary table are present in the listings table already. Therefore, I can extract the two price columns (including the one I created) and merge them with the full listings table.

# %%
room_type = bnb_listings[['id', 'room_type']]
room_type = pd.get_dummies(room_type, columns=['room_type'])
room_type.rename(columns={"room_type_Entire home/apt": 'entire_home_apt', 'room_type_Private room': 'private_room',
                          'room_type_Shared room': 'shared_room'}, inplace=True)

prop_type = bnb_listings[['id', 'property_type']]
prop_type = pd.get_dummies(prop_type, columns=['property_type'])
prop_type.rename(columns={'property_type_Apartment': 'apartment', 'property_type_Bed & Breakfast': 'bed_breakfast',
                          'property_type_Boat': 'boat', 'property_type_Bungalow': 'bungalow', 
                          'property_type_Cabin': 'cabin', 'property_type_Camper/RV': 'camper_rv', 
                          'property_type_Castle': 'castle', 'property_type_Cave': 'cave', 
                          'property_type_Condominium': 'codominium', 'property_type_Dorm': 'dorm', 
                          'property_type_House': 'house', 'property_type_Lighthouse': 'lighthouse', 
                          'property_type_Loft': 'loft', 'property_type_Other': 'other', 
                          'property_type_Tent': 'tent', 'property_type_Townhouse': 'townhouse', 
                          'property_type_Treehouse': 'treehouse', 'property_type_Villa': 'villa', 
                          'property_type_Yurt': 'yurt'}, inplace=True)

# %%
bnb_list_full = bnb_listings.merge(price_cut, on='id', how='left')
bnb_list_full = bnb_list_full.merge(room_type, on='id', how='left')
bnb_list_full = bnb_list_full.merge(prop_type, on='id', how='left')
bnb_list_full.review_scores_rating.fillna(bnb_list_full.review_scores_rating.mean(), inplace=True)
bnb_list_full.review_scores_accuracy.fillna(bnb_list_full.review_scores_accuracy.mean(), inplace=True)
bnb_list_full.review_scores_cleanliness.fillna(bnb_list_full.review_scores_cleanliness.mean(), inplace=True)
bnb_list_full.review_scores_checkin.fillna(bnb_list_full.review_scores_checkin.mean(), inplace=True)
bnb_list_full.review_scores_communication.fillna(bnb_list_full.review_scores_communication.mean(), inplace=True)
bnb_list_full.review_scores_location.fillna(bnb_list_full.review_scores_location.mean(), inplace=True)
bnb_list_full.review_scores_value.fillna(bnb_list_full.review_scores_value.mean(), inplace=True)

bnb_list_full.T
# Out:
#                                                                                0     \
# id                                                                         11187767
# listing_url                                   https://www.airbnb.com/rooms/11187767
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                             Huge Seacliff Penthouse With Views
# summary                           Amazing views from this immense 3 bedroom/ 2 b...
# space                             Spacious patio deck, library with over 300 mov...
# description                       Amazing views from this immense 3 bedroom/ 2 b...
# experiences_offered                                                            none
# neighborhood_overview             The neighborhood includes Legion of Honor, Sut...
# notes                             We require a separate rental agreement to be s...
# transit                           Public Transportation including Muni and the B...
# access                            Guests have access to the entire flat includin...
# interaction                         I am available 24 hours a day during your stay.
# house_rules                       1. Smoking is NOT allowed in the Property, Com...
# thumbnail_url                     https://a2.muscache.com/im/pictures/e8652800-a...
# medium_url                        https://a2.muscache.com/im/pictures/e8652800-a...
# picture_url                       https://a2.muscache.com/im/pictures/e8652800-a...
# xl_picture_url                    https://a2.muscache.com/im/pictures/e8652800-a...
# host_id                                                                    58242037
# host_url                                 https://www.airbnb.com/users/show/58242037
# host_name                                                                  Jonathan
# host_since                                                               2016-02-10
# host_location                              San Francisco, California, United States
# host_about                        Property Manager for Watt Property Management,...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                           100%
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a2.muscache.com/im/pictures/351d2fbc-4...
# ...                                                                             ...
# instant_bookable                                                                  t
# cancellation_policy                                                          strict
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    1
# reviews_per_month                                                              0.88
# price_y                                                                     497.368
# price_mod                                                                   497.368
# entire_home_apt                                                                   1
# private_room                                                                      0
# shared_room                                                                       0
# apartment                                                                         0
# bed_breakfast                                                                     0
# boat                                                                              0
# bungalow                                                                          0
# cabin                                                                             0
# camper_rv                                                                         0
# castle                                                                            0
# cave                                                                              0
# codominium                                                                        1
# dorm                                                                              0
# house                                                                             0
# lighthouse                                                                        0
# loft                                                                              0
# other                                                                             0
# tent                                                                              0
# townhouse                                                                         0
# treehouse                                                                         0
# villa                                                                             0
# yurt                                                                              0
#
#                                                                                1     \
# id                                                                          6938818
# listing_url                                    https://www.airbnb.com/rooms/6938818
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                                            Best Secret in Town
# summary                           My two story house is located in the quite sid...
# space                             The room is spacious and it is on the top leve...
# description                       My two story house is located in the quite sid...
# experiences_offered                                                            none
# neighborhood_overview             It is in the city and close to everything. Par...
# notes                             The summer in San Francisco is cooler than any...
# transit                           If you are on budget, the public transportatio...
# access                            You will have full access to your room, bathro...
# interaction                       I may not available in person to assist you du...
# house_rules                       1.  No pets, no smoking inside the house. 2. F...
# thumbnail_url                     https://a2.muscache.com/im/pictures/441473b8-6...
# medium_url                        https://a2.muscache.com/im/pictures/441473b8-6...
# picture_url                       https://a2.muscache.com/im/pictures/441473b8-6...
# xl_picture_url                    https://a2.muscache.com/im/pictures/441473b8-6...
# host_id                                                                    36381578
# host_url                                 https://www.airbnb.com/users/show/36381578
# host_name                                                                    Harris
# host_since                                                               2015-06-21
# host_location                              San Francisco, California, United States
# host_about                        Retired Accounting Professional. Down to earth...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                           100%
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a2.muscache.com/im/pictures/a3435acf-3...
# ...                                                                             ...
# instant_bookable                                                                  f
# cancellation_policy                                                          strict
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    2
# reviews_per_month                                                              1.85
# price_y                                                                     124.813
# price_mod                                                                   124.813
# entire_home_apt                                                                   0
# private_room                                                                      1
# shared_room                                                                       0
# apartment                                                                         0
# bed_breakfast                                                                     0
# boat                                                                              0
# bungalow                                                                          0
# cabin                                                                             0
# camper_rv                                                                         0
# castle                                                                            0
# cave                                                                              0
# codominium                                                                        0
# dorm                                                                              0
# house                                                                             1
# lighthouse                                                                        0
# loft                                                                              0
# other                                                                             0
# tent                                                                              0
# townhouse                                                                         0
# treehouse                                                                         0
# villa                                                                             0
# yurt                                                                              0
#
#                                                                                2     \
# id                                                                          9395222
# listing_url                                    https://www.airbnb.com/rooms/9395222
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                                  Ocean Beach, Lands End Escape
# summary                           Come relax in our 1 bedroom 1 bath house minut...
# space                             Huge backyard with a FirePit and lounge chairs...
# description                       Come relax in our 1 bedroom 1 bath house minut...
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                                                                           NaN
# transit                           38 Geary stop is 1 block away that will take y...
# access                            Entire 1 bedroom 1 bath, huge backyard and a p...
# interaction                                                                     NaN
# house_rules                       *No smoking please *QUITE HOURS 10pm-9am pleas...
# thumbnail_url                     https://a2.muscache.com/im/pictures/103e2c9f-2...
# medium_url                        https://a2.muscache.com/im/pictures/103e2c9f-2...
# picture_url                       https://a2.muscache.com/im/pictures/103e2c9f-2...
# xl_picture_url                    https://a2.muscache.com/im/pictures/103e2c9f-2...
# host_id                                                                    25963295
# host_url                                 https://www.airbnb.com/users/show/25963295
# host_name                                                                     Tyler
# host_since                                                               2015-01-11
# host_location                              San Francisco, California, United States
# host_about                        My husband and I go back and forth between San...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                            99%
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a2.muscache.com/im/pictures/bf8a0d2e-7...
# ...                                                                             ...
# instant_bookable                                                                  t
# cancellation_policy                                                          strict
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    1
# reviews_per_month                                                              5.87
# price_y                                                                     170.701
# price_mod                                                                   170.701
# entire_home_apt                                                                   1
# private_room                                                                      0
# shared_room                                                                       0
# apartment                                                                         0
# bed_breakfast                                                                     0
# boat                                                                              0
# bungalow                                                                          0
# cabin                                                                             0
# camper_rv                                                                         0
# castle                                                                            0
# cave                                                                              0
# codominium                                                                        0
# dorm                                                                              0
# house                                                                             1
# lighthouse                                                                        0
# loft                                                                              0
# other                                                                             0
# tent                                                                              0
# townhouse                                                                         0
# treehouse                                                                         0
# villa                                                                             0
# yurt                                                                              0
#
#                                                                                3     \
# id                                                                          8388658
# listing_url                                    https://www.airbnb.com/rooms/8388658
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                            Mid-century Seacliff near GG Bridge
# summary                           Three-bedroom in exclusive Seacliff neighborho...
# space                                                                           NaN
# description                       Three-bedroom in exclusive Seacliff neighborho...
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                                                                           NaN
# transit                                                                         NaN
# access                                                                          NaN
# interaction                                                                     NaN
# house_rules                                                                     NaN
# thumbnail_url                     https://a1.muscache.com/im/pictures/106926931/...
# medium_url                        https://a1.muscache.com/im/pictures/106926931/...
# picture_url                       https://a1.muscache.com/im/pictures/106926931/...
# xl_picture_url                    https://a1.muscache.com/im/pictures/106926931/...
# host_id                                                                     9996441
# host_url                                  https://www.airbnb.com/users/show/9996441
# host_name                                                                    Howard
# host_since                                                               2013-11-13
# host_location                              San Francisco, California, United States
# host_about                        We are a family of four, all avid travelers.  ...
# host_response_time                                                              NaN
# host_response_rate                                                              NaN
# host_acceptance_rate                                                            NaN
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a0.muscache.com/im/users/9996441/profi...
# ...                                                                             ...
# instant_bookable                                                                  f
# cancellation_policy                                                        flexible
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    1
# reviews_per_month                                                               NaN
# price_y                                                                         NaN
# price_mod                                                                       895
# entire_home_apt                                                                   1
# private_room                                                                      0
# shared_room                                                                       0
# apartment                                                                         0
# bed_breakfast                                                                     0
# boat                                                                              0
# bungalow                                                                          0
# cabin                                                                             0
# camper_rv                                                                         0
# castle                                                                            0
# cave                                                                              0
# codominium                                                                        0
# dorm                                                                              0
# house                                                                             1
# lighthouse                                                                        0
# loft                                                                              0
# other                                                                             0
# tent                                                                              0
# townhouse                                                                         0
# treehouse                                                                         0
# villa                                                                             0
# yurt                                                                              0
#
#                                                                                4     \
# id                                                                          7856443
# listing_url                                    https://www.airbnb.com/rooms/7856443
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                                      The Real San Francisco #2
# summary                           Minutes to GG Bridge, GG Park, Museums, The Pr...
# space                             Following the wild popularity of our downstair...
# description                       Minutes to GG Bridge, GG Park, Museums, The Pr...
# experiences_offered                                                            none
# neighborhood_overview             For those who love the outdoors and good food,...
# notes                                                                           NaN
# transit                           STREET PARKING Street parking in our neighborh...
# access                            Guests are permitted access to the entire main...
# interaction                       We'll be gone.  You'll hear some noise/talking...
# house_rules                       We have neighbors (a family) and guests (also ...
# thumbnail_url                     https://a2.muscache.com/im/pictures/6cf5a572-a...
# medium_url                        https://a2.muscache.com/im/pictures/6cf5a572-a...
# picture_url                       https://a2.muscache.com/im/pictures/6cf5a572-a...
# xl_picture_url                    https://a2.muscache.com/im/pictures/6cf5a572-a...
# host_id                                                                     6076870
# host_url                                  https://www.airbnb.com/users/show/6076870
# host_name                                                          Todd And Tatyana
# host_since                                                               2013-04-24
# host_location                              San Francisco, California, United States
# host_about                        We're backpackers at heart.  We've bagged over...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                           100%
# host_is_superhost                                                                 t
# host_thumbnail_url                https://a1.muscache.com/im/users/6076870/profi...
# ...                                                                             ...
# instant_bookable                                                                  f
# cancellation_policy                                                          strict
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    2
# reviews_per_month                                                              2.45
# price_y                                                                     503.478
# price_mod                                                                   503.478
# entire_home_apt                                                                   1
# private_room                                                                      0
# shared_room                                                                       0
# apartment                                                                         1
# bed_breakfast                                                                     0
# boat                                                                              0
# bungalow                                                                          0
# cabin                                                                             0
# camper_rv                                                                         0
# castle                                                                            0
# cave                                                                              0
# codominium                                                                        0
# dorm                                                                              0
# house                                                                             0
# lighthouse                                                                        0
# loft                                                                              0
# other                                                                             0
# tent                                                                              0
# townhouse                                                                         0
# treehouse                                                                         0
# villa                                                                             0
# yurt                                                                              0
#
#                                                                                5     \
# id                                                                          4781448
# listing_url                                    https://www.airbnb.com/rooms/4781448
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                            3 Bd 2.5 Ba Full Flat Condo w Views
# summary                           Our family-friendly condo is located in San Fr...
# space                             Open concept living, dining area has great cit...
# description                       Our family-friendly condo is located in San Fr...
# experiences_offered                                                            none
# neighborhood_overview             We are located across the street from Lincoln ...
# notes                             2 night minimum stay please. San Francisco Sho...
# transit                           Easy bus access to the entire city with 3 bus ...
# access                                       Guests have access to the entire home.
# interaction                       We are happy hosts to our city and can give gr...
# house_rules                       • Check-in time is 4PM. This is our home, so w...
# thumbnail_url                     https://a2.muscache.com/im/pictures/71426241/2...
# medium_url                        https://a2.muscache.com/im/pictures/71426241/2...
# picture_url                       https://a2.muscache.com/im/pictures/71426241/2...
# xl_picture_url                    https://a2.muscache.com/im/pictures/71426241/2...
# host_id                                                                    13112558
# host_url                                 https://www.airbnb.com/users/show/13112558
# host_name                                                                       Pam
# host_since                                                               2014-03-14
# host_location                              San Francisco, California, United States
# host_about                        I like experiencing the authentic culture of t...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                            95%
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a0.muscache.com/im/users/13112558/prof...
# ...                                                                             ...
# instant_bookable                                                                  f
# cancellation_policy                                                          strict
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    1
# reviews_per_month                                                              0.55
# price_y                                                                         327
# price_mod                                                                       327
# entire_home_apt                                                                   1
# private_room                                                                      0
# shared_room                                                                       0
# apartment                                                                         1
# bed_breakfast                                                                     0
# boat                                                                              0
# bungalow                                                                          0
# cabin                                                                             0
# camper_rv                                                                         0
# castle                                                                            0
# cave                                                                              0
# codominium                                                                        0
# dorm                                                                              0
# house                                                                             0
# lighthouse                                                                        0
# loft                                                                              0
# other                                                                             0
# tent                                                                              0
# townhouse                                                                         0
# treehouse                                                                         0
# villa                                                                             0
# yurt                                                                              0
#
#                                                                                6     \
# id                                                                          1427660
# listing_url                                    https://www.airbnb.com/rooms/1427660
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                             Charming Studio Apt at Ocean Beach
# summary                           Charming, private, peaceful hideaway 2 blocks ...
# space                             Dear Guests, This quiet and private, 1 bedroom...
# description                       Charming, private, peaceful hideaway 2 blocks ...
# experiences_offered                                                            none
# neighborhood_overview             I'm excited for you to discover why I love liv...
# notes                             The studio is not equipped for cooking, nor do...
# transit                           Public transport by bus to take you anywhere i...
# access                            Guests enter and exit the private studio via m...
# interaction                       You decide how much socialization or privacy y...
# house_rules                       Absolutely NO SMOKING or drugs on property - p...
# thumbnail_url                     https://a2.muscache.com/im/pictures/65878462/5...
# medium_url                        https://a2.muscache.com/im/pictures/65878462/5...
# picture_url                       https://a2.muscache.com/im/pictures/65878462/5...
# xl_picture_url                    https://a2.muscache.com/im/pictures/65878462/5...
# host_id                                                                     2275604
# host_url                                  https://www.airbnb.com/users/show/2275604
# host_name                                                                    Laurie
# host_since                                                               2012-05-02
# host_location                              San Francisco, California, United States
# host_about                        I LOVE San Francisco!! I mean, I am IN LOVE wi...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                           100%
# host_is_superhost                                                                 t
# host_thumbnail_url                https://a1.muscache.com/im/users/2275604/profi...
# ...                                                                             ...
# instant_bookable                                                                  f
# cancellation_policy                                                        flexible
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    1
# reviews_per_month                                                              6.81
# price_y                                                                         150
# price_mod                                                                       150
# entire_home_apt                                                                   1
# private_room                                                                      0
# shared_room                                                                       0
# apartment                                                                         0
# bed_breakfast                                                                     0
# boat                                                                              0
# bungalow                                                                          0
# cabin                                                                             0
# camper_rv                                                                         0
# castle                                                                            0
# cave                                                                              0
# codominium                                                                        0
# dorm                                                                              0
# house                                                                             1
# lighthouse                                                                        0
# loft                                                                              0
# other                                                                             0
# tent                                                                              0
# townhouse                                                                         0
# treehouse                                                                         0
# villa                                                                             0
# yurt                                                                              0
#
#                                                                                7     \
# id                                                                          8087607
# listing_url                                    https://www.airbnb.com/rooms/8087607
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                              Single Room Beautiful Beach Condo
# summary                           When I travel, my quiet beach side condo makes...
# space                                                                           NaN
# description                       When I travel, my quiet beach side condo makes...
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                                                                           NaN
# transit                                                                         NaN
# access                                                                          NaN
# interaction                                                                     NaN
# house_rules                                                                     NaN
# thumbnail_url                     https://a1.muscache.com/im/pictures/103040877/...
# medium_url                        https://a1.muscache.com/im/pictures/103040877/...
# picture_url                       https://a1.muscache.com/im/pictures/103040877/...
# xl_picture_url                    https://a1.muscache.com/im/pictures/103040877/...
# host_id                                                                     3264449
# host_url                                  https://www.airbnb.com/users/show/3264449
# host_name                                                                     Keith
# host_since                                                               2012-08-15
# host_location                                                          Tokyo, Japan
# host_about                        i'm a software engineer that works on (SENSITI...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                           100%
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a2.muscache.com/im/pictures/5b9b9ea1-0...
# ...                                                                             ...
# instant_bookable                                                                  f
# cancellation_policy                                                        flexible
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    1
# reviews_per_month                                                               NaN
# price_y                                                                         NaN
# price_mod                                                                        79
# entire_home_apt                                                                   0
# private_room                                                                      1
# shared_room                                                                       0
# apartment                                                                         1
# bed_breakfast                                                                     0
# boat                                                                              0
# bungalow                                                                          0
# cabin                                                                             0
# camper_rv                                                                         0
# castle                                                                            0
# cave                                                                              0
# codominium                                                                        0
# dorm                                                                              0
# house                                                                             0
# lighthouse                                                                        0
# loft                                                                              0
# other                                                                             0
# tent                                                                              0
# townhouse                                                                         0
# treehouse                                                                         0
# villa                                                                             0
# yurt                                                                              0
#
#                                                                                8     \
# id                                                                          9904485
# listing_url                                    https://www.airbnb.com/rooms/9904485
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                                                    Great Room!
# summary                                    Quite house, clean room, nice roommates.
# space                                                                           NaN
# description                                Quite house, clean room, nice roommates.
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                                                                           NaN
# transit                                                                         NaN
# access                                                                          NaN
# interaction                                                                     NaN
# house_rules                                                                     NaN
# thumbnail_url                     https://a2.muscache.com/im/pictures/49cd30d8-2...
# medium_url                        https://a2.muscache.com/im/pictures/49cd30d8-2...
# picture_url                       https://a2.muscache.com/im/pictures/49cd30d8-2...
# xl_picture_url                    https://a2.muscache.com/im/pictures/49cd30d8-2...
# host_id                                                                    13046907
# host_url                                 https://www.airbnb.com/users/show/13046907
# host_name                                                                      John
# host_since                                                               2014-03-12
# host_location                              San Francisco, California, United States
# host_about                        Hello!\r\n\r\nI am currently in grad school pu...
# host_response_time                                                              NaN
# host_response_rate                                                              NaN
# host_acceptance_rate                                                            NaN
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a0.muscache.com/im/users/13046907/prof...
# ...                                                                             ...
# instant_bookable                                                                  f
# cancellation_policy                                                        flexible
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    2
# reviews_per_month                                                               NaN
# price_y                                                                         NaN
# price_mod                                                                       195
# entire_home_apt                                                                   0
# private_room                                                                      1
# shared_room                                                                       0
# apartment                                                                         0
# bed_breakfast                                                                     0
# boat                                                                              0
# bungalow                                                                          0
# cabin                                                                             0
# camper_rv                                                                         0
# castle                                                                            0
# cave                                                                              0
# codominium                                                                        0
# dorm                                                                              0
# house                                                                             1
# lighthouse                                                                        0
# ...
# listing_url                                   https://www.airbnb.com/rooms/13203823
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                        Beautiful Big Boat -  Fort Mason/Marina
# summary                           Want to go for a run to the Golden Gate Bridge...
# space                             This is a very nice place to stay.  Even thoug...
# description                       Want to go for a run to the Golden Gate Bridge...
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                             If the day proves to be a sunny one, you have ...
# transit                                                                         NaN
# access                            Please think of the Boat as a hotel room with ...
# interaction                       You will be able to reach my on cell phone any...
# house_rules                       - Please respect neighbors.  This is a beautif...
# thumbnail_url                     https://a2.muscache.com/im/pictures/03e607fc-3...
# medium_url                        https://a2.muscache.com/im/pictures/03e607fc-3...
# picture_url                       https://a2.muscache.com/im/pictures/03e607fc-3...
# xl_picture_url                    https://a2.muscache.com/im/pictures/03e607fc-3...
# host_id                                                                     4408364
# host_url                                  https://www.airbnb.com/users/show/4408364
# host_name                                                                    Wesley
# host_since                                                               2012-12-15
# host_location                              San Francisco, California, United States
# host_about                                                                      NaN
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                           100%
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a2.muscache.com/im/pictures/49fb8ae0-e...
# ...                                                                             ...
# instant_bookable                                                                  f
# cancellation_policy                                                        flexible
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    1
# reviews_per_month                                                                 3
# price_y                                                                         NaN
# price_mod                                                                       132
# entire_home_apt                                                                   1
# private_room                                                                      0
# shared_room                                                                       0
# apartment                                                                         0
# bed_breakfast                                                                     0
# boat                                                                              1
# bungalow                                                                          0
# cabin                                                                             0
# camper_rv                                                                         0
# castle                                                                            0
# cave                                                                              0
# codominium                                                                        0
# dorm                                                                              0
# house                                                                             0
# lighthouse                                                                        0
# loft                                                                              0
# other                                                                             0
# tent                                                                              0
# townhouse                                                                         0
# treehouse                                                                         0
# villa                                                                             0
# yurt                                                                              0
#
#                                                                                8617  \
# id                                                                         13671441
# listing_url                                   https://www.airbnb.com/rooms/13671441
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                              15 min to SF DT / Hacker House M1
# summary                           Our guests are young and smart startup founder...
# space                                                                           NaN
# description                       Our guests are young and smart startup founder...
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                                                                           NaN
# transit                                                                         NaN
# access                                                                          NaN
# interaction                                                                     NaN
# house_rules                                                                     NaN
# thumbnail_url                     https://a2.muscache.com/im/pictures/a6511356-7...
# medium_url                        https://a2.muscache.com/im/pictures/a6511356-7...
# picture_url                       https://a2.muscache.com/im/pictures/a6511356-7...
# xl_picture_url                    https://a2.muscache.com/im/pictures/a6511356-7...
# host_id                                                                     5932384
# host_url                                  https://www.airbnb.com/users/show/5932384
# host_name                                                                    Sergey
# host_since                                                               2013-04-15
# host_location                              San Francisco, California, United States
# host_about                        Hello for everyone.\r\nI am co-founder of Hack...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                            70%
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a2.muscache.com/im/pictures/34c02028-d...
# ...                                                                             ...
# instant_bookable                                                                  f
# cancellation_policy                                                        moderate
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                   29
# reviews_per_month                                                               NaN
# price_y                                                                     36.3918
# price_mod                                                                   36.3918
# entire_home_apt                                                                   0
# private_room                                                                      0
# shared_room                                                                       1
# apartment                                                                         0
# bed_breakfast                                                                     0
# boat                                                                              0
# bungalow                                                                          0
# cabin                                                                             0
# camper_rv                                                                         0
# castle                                                                            0
# cave                                                                              0
# codominium                                                                        0
# dorm                                                                              0
# house                                                                             1
# lighthouse                                                                        0
# loft                                                                              0
# other                                                                             0
# tent                                                                              0
# townhouse                                                                         0
# treehouse                                                                         0
# villa                                                                             0
# yurt                                                                              0
#
#                                                                                8618
# id                                                                         13714376
# listing_url                                   https://www.airbnb.com/rooms/13714376
# scrape_id                                                            20160702162156
# last_scraped                                                             2016-07-02
# name                                              15 min to SF DT / Hacker House M5
# summary                           My place is close to Bart station . You’ll lov...
# space                                                                           NaN
# description                       My place is close to Bart station . You’ll lov...
# experiences_offered                                                            none
# neighborhood_overview                                                           NaN
# notes                                                                           NaN
# transit                                                                         NaN
# access                                                                          NaN
# interaction                                                                     NaN
# house_rules                                                                     NaN
# thumbnail_url                     https://a2.muscache.com/im/pictures/196267ee-1...
# medium_url                        https://a2.muscache.com/im/pictures/196267ee-1...
# picture_url                       https://a2.muscache.com/im/pictures/196267ee-1...
# xl_picture_url                    https://a2.muscache.com/im/pictures/196267ee-1...
# host_id                                                                     5932384
# host_url                                  https://www.airbnb.com/users/show/5932384
# host_name                                                                    Sergey
# host_since                                                               2013-04-15
# host_location                              San Francisco, California, United States
# host_about                        Hello for everyone.\r\nI am co-founder of Hack...
# host_response_time                                                   within an hour
# host_response_rate                                                             100%
# host_acceptance_rate                                                            70%
# host_is_superhost                                                                 f
# host_thumbnail_url                https://a2.muscache.com/im/pictures/34c02028-d...
# ...                                                                             ...
# instant_bookable                                                                  f
# cancellation_policy                                                        moderate
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                   29
# reviews_per_month                                                               NaN
# price_y                                                                     48.5465
# price_mod                                                                   48.5465
# entire_home_apt                                                                   0
# private_room                                                                      0
# shared_room                                                                       1
# apartment                                                                         0
# bed_breakfast                                                                     0
# boat                                                                              0
# bungalow                                                                          0
# cabin                                                                             0
# camper_rv                                                                         0
# castle                                                                            0
# cave                                                                              0
# codominium                                                                        0
# dorm                                                                              0
# house                                                                             1
# lighthouse                                                                        0
# loft                                                                              0
# other                                                                             0
# tent                                                                              0
# townhouse                                                                         0
# treehouse                                                                         0
# villa                                                                             0
# yurt                                                                              0
#
# [119 rows x 8619 columns]

# %% [markdown]
# Need to convert some of the money features into float data types. Quick function below to convert the dollar columns to floats.

# %%
def conv_to_float(s):
    if s:
        return float(s)
    else:
        return s
    
def conv_dollars(df, list_of_cols):
    for col in list_of_cols:
        df[col] = df[col].replace(to_replace=r'[^0-9.]+', value='', regex=True)
        df[col] = df[col].apply(conv_to_float)
    return df

# %%
bnb_list_full = conv_dollars(bnb_list_full, ['price', 'weekly_price', 'monthly_price', 
                                             'security_deposit', 'cleaning_fee', 'extra_people'])
bnb_list_full.T.tail(60)
# Out:
#                                            0     \
# square_feet                                 NaN
# price                                       400
# weekly_price                                NaN
# monthly_price                               NaN
# security_deposit                            NaN
# cleaning_fee                                200
# guests_included                               1
# extra_people                                  0
# minimum_nights                                2
# maximum_nights                               28
# calendar_updated                          today
# has_availability                            NaN
# availability_30                               8
# availability_60                              31
# availability_90                              61
# availability_365                            152
# calendar_last_scraped                2016-07-02
# number_of_reviews                             3
# first_review                         2016-03-23
# last_review                          2016-06-25
# review_scores_rating                         80
# review_scores_accuracy                        9
# review_scores_cleanliness                     9
# review_scores_checkin                         9
# review_scores_communication                   9
# review_scores_location                        9
# review_scores_value                           8
# requires_license                              t
# license                                     NaN
# jurisdiction_names                SAN FRANCISCO
# instant_bookable                              t
# cancellation_policy                      strict
# require_guest_profile_picture                 f
# require_guest_phone_verification              f
# calculated_host_listings_count                1
# reviews_per_month                          0.88
# price_y                                 497.368
# price_mod                               497.368
# entire_home_apt                               1
# private_room                                  0
# shared_room                                   0
# apartment                                     0
# bed_breakfast                                 0
# boat                                          0
# bungalow                                      0
# cabin                                         0
# camper_rv                                     0
# castle                                        0
# cave                                          0
# codominium                                    1
# dorm                                          0
# house                                         0
# lighthouse                                    0
# loft                                          0
# other                                         0
# tent                                          0
# townhouse                                     0
# treehouse                                     0
# villa                                         0
# yurt                                          0
#
#                                                                                1     \
# square_feet                                                                     NaN
# price                                                                            99
# weekly_price                                                                    700
# monthly_price                                                                   NaN
# security_deposit                                                                NaN
# cleaning_fee                                                                     20
# guests_included                                                                   2
# extra_people                                                                     20
# minimum_nights                                                                    3
# maximum_nights                                                                   30
# calendar_updated                                                        2 weeks ago
# has_availability                                                                NaN
# availability_30                                                                   2
# availability_60                                                                   7
# availability_90                                                                   8
# availability_365                                                                187
# calendar_last_scraped                                                    2016-07-02
# number_of_reviews                                                                23
# first_review                                                             2015-06-27
# last_review                                                              2016-06-16
# review_scores_rating                                                             91
# review_scores_accuracy                                                            9
# review_scores_cleanliness                                                         9
# review_scores_checkin                                                            10
# review_scores_communication                                                      10
# review_scores_location                                                            9
# review_scores_value                                                               9
# requires_license                                                                  t
# license                           S. F. Short-Term Residential Rental Registrati...
# jurisdiction_names                                                    SAN FRANCISCO
# instant_bookable                                                                  f
# cancellation_policy                                                          strict
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    2
# reviews_per_month                                                              1.85
# price_y                                                                     124.813
# price_mod                                                                   124.813
# entire_home_apt                                                                   0
# private_room                                                                      1
# shared_room                                                                       0
# apartment                                                                         0
# bed_breakfast                                                                     0
# boat                                                                              0
# bungalow                                                                          0
# cabin                                                                             0
# camper_rv                                                                         0
# castle                                                                            0
# cave                                                                              0
# codominium                                                                        0
# dorm                                                                              0
# house                                                                             1
# lighthouse                                                                        0
# loft                                                                              0
# other                                                                             0
# tent                                                                              0
# townhouse                                                                         0
# treehouse                                                                         0
# villa                                                                             0
# yurt                                                                              0
#
#                                            2              3              4     \
# square_feet                                 NaN            NaN            NaN
# price                                       155            895            195
# weekly_price                               1050           6000            NaN
# monthly_price                              4000            NaN            NaN
# security_deposit                            NaN            250            250
# cleaning_fee                                 25            125            150
# guests_included                               2              1              1
# extra_people                                 10              0              0
# minimum_nights                                1              3              2
# maximum_nights                             1125             14           1125
# calendar_updated                     5 days ago   6 months ago     6 days ago
# has_availability                            NaN            NaN            NaN
# availability_30                               0              0              2
# availability_60                               6              0              2
# availability_90                              20              0              9
# availability_365                            167              0             23
# calendar_last_scraped                2016-07-02     2016-07-02     2016-07-02
# number_of_reviews                            45              0              4
# first_review                         2015-11-16            NaN     2016-05-15
# last_review                          2016-06-19            NaN     2016-06-22
# review_scores_rating                         88        94.0024            100
# review_scores_accuracy                        9        9.58931             10
# review_scores_cleanliness                     9        9.41372             10
# review_scores_checkin                        10        9.72694             10
# review_scores_communication                  10        9.74964             10
# review_scores_location                       10        9.50056             10
# review_scores_value                           9         9.3029             10
# requires_license                              t              t              t
# license                                     NaN            NaN            NaN
# jurisdiction_names                SAN FRANCISCO  SAN FRANCISCO  SAN FRANCISCO
# instant_bookable                              t              f              f
# cancellation_policy                      strict       flexible         strict
# require_guest_profile_picture                 f              f              f
# require_guest_phone_verification              f              f              f
# calculated_host_listings_count                1              1              2
# reviews_per_month                          5.87            NaN           2.45
# price_y                                 170.701            NaN        503.478
# price_mod                               170.701            895        503.478
# entire_home_apt                               1              1              1
# private_room                                  0              0              0
# shared_room                                   0              0              0
# apartment                                     0              0              1
# bed_breakfast                                 0              0              0
# boat                                          0              0              0
# bungalow                                      0              0              0
# cabin                                         0              0              0
# camper_rv                                     0              0              0
# castle                                        0              0              0
# cave                                          0              0              0
# codominium                                    0              0              0
# dorm                                          0              0              0
# house                                         1              1              0
# lighthouse                                    0              0              0
# loft                                          0              0              0
# other                                         0              0              0
# tent                                          0              0              0
# townhouse                                     0              0              0
# treehouse                                     0              0              0
# villa                                         0              0              0
# yurt                                          0              0              0
#
#                                                                                5     \
# square_feet                                                                     NaN
# price                                                                           395
# weekly_price                                                                    NaN
# monthly_price                                                                   NaN
# security_deposit                                                               1000
# cleaning_fee                                                                    150
# guests_included                                                                   4
# extra_people                                                                     25
# minimum_nights                                                                    3
# maximum_nights                                                                   18
# calendar_updated                                                         2 days ago
# has_availability                                                                NaN
# availability_30                                                                   0
# availability_60                                                                   0
# availability_90                                                                   5
# availability_365                                                                  5
# calendar_last_scraped                                                    2016-07-02
# number_of_reviews                                                                 6
# first_review                                                             2015-08-11
# last_review                                                              2016-04-04
# review_scores_rating                                                            100
# review_scores_accuracy                                                           10
# review_scores_cleanliness                                                        10
# review_scores_checkin                                                            10
# review_scores_communication                                                      10
# review_scores_location                                                           10
# review_scores_value                                                              10
# requires_license                                                                  t
# license                           San Francisco Short-Term Residential Rental Re...
# jurisdiction_names                                                    SAN FRANCISCO
# instant_bookable                                                                  f
# cancellation_policy                                                          strict
# require_guest_profile_picture                                                     f
# require_guest_phone_verification                                                  f
# calculated_host_listings_count                                                    1
# reviews_per_month                                                              0.55
# price_y                                                                         327
# price_mod                                                                       327
# entire_home_apt                                                                   1
# private_room                                                                      0
# shared_room                                                                       0
# apartment                                                                         1
# bed_breakfast                                                                     0
# boat                                                                              0
# bungalow                                                                          0
# cabin                                                                             0
# camper_rv                                                                         0
# castle                                                                            0
# cave                                                                              0
# codominium                                                                        0
# dorm                                                                              0
# house                                                                             0
# lighthouse                                                                        0
# loft                                                                              0
# other                                                                             0
# tent                                                                              0
# townhouse                                                                         0
# treehouse                                                                         0
# villa                                                                             0
# yurt                                                                              0
#
#                                            6              7              8     \
# square_feet                                 NaN            NaN            NaN
# price                                       150             79            195
# weekly_price                                875            NaN            NaN
# monthly_price                               NaN            NaN            NaN
# security_deposit                            200            NaN            NaN
# cleaning_fee                                NaN            NaN            NaN
# guests_included                               2              1              1
# extra_people                                 10              0              0
# minimum_nights                                2              1              1
# maximum_nights                                7           1125           1125
# calendar_updated                    2 weeks ago  10 months ago   7 months ago
# has_availability                            NaN            NaN            NaN
# availability_30                               1              0              0
# availability_60                               4              0              0
# availability_90                               8              0              0
# availability_365                            259              0              0
# calendar_last_scraped                2016-07-02     2016-07-02     2016-07-02
# number_of_reviews                           236              0              0
# first_review                         2013-08-28            NaN            NaN
# last_review                          2016-06-24            NaN            NaN
# review_scores_rating                         98        94.0024        94.0024
# review_scores_accuracy                       10        9.58931        9.58931
# review_scores_cleanliness                    10        9.41372        9.41372
# review_scores_checkin                        10        9.72694        9.72694
# review_scores_communication                  10        9.74964        9.74964
# review_scores_location                       10        9.50056        9.50056
# review_scores_value                          10         9.3029         9.3029
# requires_license                              t              t              t
# license                             STR-0000026            NaN            NaN
# jurisdiction_names                SAN FRANCISCO  SAN FRANCISCO  SAN FRANCISCO
# instant_bookable                              f              f              f
# cancellation_policy                    flexible       flexible       flexible
# require_guest_profile_picture                 f              f              f
# require_guest_phone_verification              f              f              f
# calculated_host_listings_count                1              1              2
# reviews_per_month                          6.81            NaN            NaN
# price_y                                     150            NaN            NaN
# price_mod                                   150             79            195
# entire_home_apt                               1              0              0
# private_room                                  0              1              1
# shared_room                                   0              0              0
# apartment                                     0              1              0
# bed_breakfast                                 0              0              0
# boat                                          0              0              0
# bungalow                                      0              0              0
# cabin                                         0              0              0
# camper_rv                                     0              0              0
# castle                                        0              0              0
# cave                                          0              0              0
# codominium                                    0              0              0
# dorm                                          0              0              0
# house                                         1              0              1
# lighthouse                                    0              0              0
# loft                                          0              0              0
# other                                         0              0              0
# tent                                          0              0              0
# townhouse                                     0              0              0
# treehouse                                     0              0              0
# villa                                         0              0              0
# yurt                                          0              0              0
#
#                                            9        ...            8609  \
# square_feet                                 NaN     ...             NaN
# price                                       192     ...              64
# weekly_price                               1333     ...             NaN
# monthly_price                              4704     ...             NaN
# security_deposit                            250     ...             100
# cleaning_fee                                 65     ...              75
# guests_included                               1     ...               1
# extra_people                                 15     ...               0
# minimum_nights                                3     ...               7
# maximum_nights                               29     ...              15
# calendar_updated                     5 days ago     ...       yesterday
# has_availability                            NaN     ...             NaN
# availability_30                               0     ...              24
# availability_60                              12     ...              54
# availability_90                              42     ...              84
# availability_365                            128     ...              84
# calendar_last_scraped                2016-07-02     ...      2016-07-02
# number_of_reviews                            80     ...               0
# first_review                         2014-08-26     ...             NaN
# last_review                          2016-07-02     ...             NaN
# review_scores_rating                         96     ...         94.0024
# review_scores_accuracy                       10     ...         9.58931
# review_scores_cleanliness                    10     ...         9.41372
# review_scores_checkin                        10     ...         9.72694
# review_scores_communication                  10     ...         9.74964
# review_scores_location                       10     ...         9.50056
# review_scores_value                           9     ...          9.3029
# requires_license                              t     ...               f
# license                                     NaN     ...             NaN
# jurisdiction_names                SAN FRANCISCO     ...             NaN
# instant_bookable                              f     ...               t
# cancellation_policy                      strict     ...        flexible
# require_guest_profile_picture                 f     ...               f
# require_guest_phone_verification              f     ...               f
# calculated_host_listings_count                2     ...               1
# reviews_per_month                          3.55     ...             NaN
# price_y                                 189.875     ...              64
# price_mod                               189.875     ...              64
# entire_home_apt                               1     ...               0
# private_room                                  0     ...               1
# shared_room                                   0     ...               0
# apartment                                     1     ...               0
# bed_breakfast                                 0     ...               0
# boat                                          0     ...               0
# bungalow                                      0     ...               0
# cabin                                         0     ...               0
# camper_rv                                     0     ...               0
# castle                                        0     ...               0
# cave                                          0     ...               0
# codominium                                    0     ...               0
# dorm                                          0     ...               0
# house                                         0     ...               1
# lighthouse                                    0     ...               0
# loft                                          0     ...               0
# other                                         0     ...               0
# tent                                          0     ...               0
# townhouse                                     0     ...               0
# treehouse                                     0     ...               0
# villa                                         0     ...               0
# yurt                                          0     ...               0
#
#                                            8610        8611        8612  \
# square_feet                                 NaN         NaN         NaN
# price                                        80          85         320
# weekly_price                                NaN         NaN         NaN
# monthly_price                               NaN         NaN         NaN
# security_deposit                            100         NaN         400
# cleaning_fee                                NaN          30          85
# guests_included                               1           1           6
# extra_people                                  0           0          20
# minimum_nights                                1           1           3
# maximum_nights                                2        1125          29
# calendar_updated                     a week ago  a week ago  3 days ago
# has_availability                            NaN         NaN         NaN
# availability_30                               0          15          12
# availability_60                               0          19          39
# availability_90                               0          49          69
# availability_365                              0         324          70
# calendar_last_scraped                2016-07-02  2016-07-02  2016-07-02
# number_of_reviews                             0           0           0
# first_review                                NaN         NaN         NaN
# last_review                                 NaN         NaN         NaN
# review_scores_rating                    94.0024     94.0024     94.0024
# review_scores_accuracy                  9.58931     9.58931     9.58931
# review_scores_cleanliness               9.41372     9.41372     9.41372
# review_scores_checkin                   9.72694     9.72694     9.72694
# review_scores_communication             9.74964     9.74964     9.74964
# review_scores_location                  9.50056     9.50056     9.50056
# review_scores_value                      9.3029      9.3029      9.3029
# requires_license                              t           f           f
# license                                     NaN         NaN         NaN
# jurisdiction_names                SAN FRANCISCO         NaN         NaN
# instant_bookable                              t           f           f
# cancellation_policy                    flexible    moderate      strict
# require_guest_profile_picture                 f           f           f
# require_guest_phone_verification              f           f           f
# calculated_host_listings_count                1           3           1
# reviews_per_month                           NaN         NaN         NaN
# price_y                                     NaN     86.4506     362.357
# price_mod                                    80     86.4506     362.357
# entire_home_apt                               0           0           1
# private_room                                  1           1           0
# shared_room                                   0           0           0
# apartment                                     0           1           0
# bed_breakfast                                 0           0           0
# boat                                          1           0           0
# bungalow                                      0           0           0
# cabin                                         0           0           0
# camper_rv                                     0           0           0
# castle                                        0           0           0
# cave                                          0           0           0
# codominium                                    0           0           0
# dorm                                          0           0           0
# house                                         0           0           1
# lighthouse                                    0           0           0
# loft                                          0           0           0
# other                                         0           0           0
# tent                                          0           0           0
# townhouse                                     0           0           0
# treehouse                                     0           0           0
# villa                                         0           0           0
# yurt                                          0           0           0
#
#                                         8613           8614        8615  \
# square_feet                              NaN            NaN         NaN
# price                                     35            199          35
# weekly_price                             NaN            NaN         NaN
# monthly_price                            NaN            NaN         NaN
# security_deposit                         NaN            100         NaN
# cleaning_fee                              20             50          20
# guests_included                            1              1           1
# extra_people                              40              0          40
# minimum_nights                             5              3           5
# maximum_nights                          1125           1125        1125
# calendar_updated                  6 days ago     a week ago  6 days ago
# has_availability                         NaN            NaN         NaN
# availability_30                           30              7          23
# availability_60                           53              7          53
# availability_90                           83             23          83
# availability_365                         358             23         358
# calendar_last_scraped             2016-07-02     2016-07-02  2016-07-02
# number_of_reviews                          0              1           0
# first_review                             NaN     2016-06-21         NaN
# last_review                              NaN     2016-06-21         NaN
# review_scores_rating                 94.0024            100     94.0024
# review_scores_accuracy               9.58931             10     9.58931
# review_scores_cleanliness            9.41372             10     9.41372
# review_scores_checkin                9.72694             10     9.72694
# review_scores_communication          9.74964             10     9.74964
# review_scores_location               9.50056             10     9.50056
# review_scores_value                   9.3029             10      9.3029
# requires_license                           f              t           f
# license                                  NaN            NaN         NaN
# jurisdiction_names                       NaN  SAN FRANCISCO         NaN
# instant_bookable                           f              f           f
# cancellation_policy                 moderate       moderate    moderate
# require_guest_profile_picture              f              f           f
# require_guest_phone_verification           f              f           f
# calculated_host_listings_count            29              1          29
# reviews_per_month                        NaN              1         NaN
# price_y                              35.1955            229     34.1983
# price_mod                            35.1955            229     34.1983
# entire_home_apt                            0              1           0
# private_room                               0              0           0
# shared_room                                1              0           1
# apartment                                  0              0           0
# bed_breakfast                              0              0           0
# boat                                       0              1           0
# bungalow                                   0              0           0
# cabin                                      0              0           0
# camper_rv                                  0              0           0
# castle                                     0              0           0
# cave                                       0              0           0
# codominium                                 0              0           0
# dorm                                       0              0           0
# house                                      1              0           1
# lighthouse                                 0              0           0
# loft                                       0              0           0
# other                                      0              0           0
# tent                                       0              0           0
# townhouse                                  0              0           0
# treehouse                                  0              0           0
# villa                                      0              0           0
# yurt                                       0              0           0
#
#                                            8616        8617        8618
# square_feet                                 NaN         NaN         NaN
# price                                       132          35          35
# weekly_price                                NaN         NaN         NaN
# monthly_price                               NaN         NaN         NaN
# security_deposit                            100         NaN         NaN
# cleaning_fee                                 50          20          20
# guests_included                               1           1           1
# extra_people                                  0          40          40
# minimum_nights                                1           7           2
# maximum_nights                                3        1125        1125
# calendar_updated                     5 days ago  6 days ago  6 days ago
# has_availability                            NaN         NaN         NaN
# availability_30                               0          25          26
# availability_60                               0          51          56
# availability_90                               0          81          86
# availability_365                              0         171          86
# calendar_last_scraped                2016-07-02  2016-07-02  2016-07-02
# number_of_reviews                             3           0           0
# first_review                         2016-06-16         NaN         NaN
# last_review                          2016-06-25         NaN         NaN
# review_scores_rating                        100     94.0024     94.0024
# review_scores_accuracy                       10     9.58931     9.58931
# review_scores_cleanliness                    10     9.41372     9.41372
# review_scores_checkin                        10     9.72694     9.72694
# review_scores_communication                  10     9.74964     9.74964
# review_scores_location                       10     9.50056     9.50056
# review_scores_value                           9      9.3029      9.3029
# requires_license                              t           f           f
# license                                     NaN         NaN         NaN
# jurisdiction_names                SAN FRANCISCO         NaN         NaN
# instant_bookable                              f           f           f
# cancellation_policy                    flexible    moderate    moderate
# require_guest_profile_picture                 f           f           f
# require_guest_phone_verification              f           f           f
# calculated_host_listings_count                1          29          29
# reviews_per_month                             3         NaN         NaN
# price_y                                     NaN     36.3918     48.5465
# price_mod                                   132     36.3918     48.5465
# entire_home_apt                               1           0           0
# private_room                                  0           0           0
# shared_room                                   0           1           1
# apartment                                     0           0           0
# bed_breakfast                                 0           0           0
# boat                                          1           0           0
# bungalow                                      0           0           0
# cabin                                         0           0           0
# camper_rv                                     0           0           0
# castle                                        0           0           0
# cave                                          0           0           0
# codominium                                    0           0           0
# dorm                                          0           0           0
# house                                         0           1           1
# lighthouse                                    0           0           0
# loft                                          0           0           0
# other                                         0           0           0
# tent                                          0           0           0
# townhouse                                     0           0           0
# treehouse                                     0           0           0
# villa                                         0           0           0
# yurt                                          0           0           0
#
# [60 rows x 8619 columns]

# %% [markdown]
# Could use bed_type and amenities if I wanted to generate more features from categorical values. Converted room_type and proper_type to categorical feature columns with boolean values. This could possibly be restructured with a different method or changed to a more appropriate method that takes into account for categories that are rare (sparse columns when using boolean values).
#
# Square_feet would be a great predictor to use, and will likely be availabe with real estate listings, should consider this a large caveat.
#
# Some listings have never been reviewed, which represents a bit of a challenge considering they are valueable pieces of data I don't want to simply discard. For now I will impute mean rating values for each column into missing values (NaNs).

# %%
bnb_list_full.columns.values
# Out:
# array(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered',
#        'neighborhood_overview', 'notes', 'transit', 'access',
#        'interaction', 'house_rules', 'thumbnail_url', 'medium_url',
#        'picture_url', 'xl_picture_url', 'host_id', 'host_url', 'host_name',
#        'host_since', 'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic',
#        'host_identity_verified', 'street', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'city',
#        'state', 'zipcode', 'market', 'smart_location', 'country_code',
#        'country', 'latitude', 'longitude', 'is_location_exact',
#        'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet', 'price',
#        'weekly_price', 'monthly_price', 'security_deposit', 'cleaning_fee',
#        'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'cancellation_policy', 'require_guest_profile_picture',
#        'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month', 'price_y',
#        'price_mod', 'entire_home_apt', 'private_room', 'shared_room',
#        'apartment', 'bed_breakfast', 'boat', 'bungalow', 'cabin',
#        'camper_rv', 'castle', 'cave', 'codominium', 'dorm', 'house',
#        'lighthouse', 'loft', 'other', 'tent', 'townhouse', 'treehouse',
#        'villa', 'yurt'], dtype=object)

# %%
num_cols = ['host_total_listings_count','latitude', 'longitude', 'accommodates', 'bathrooms',
            'bedrooms', 'beds', 'amenities', 'price','guests_included', 'extra_people', 
            'minimum_nights','maximum_nights', 
            'availability_30', 'availability_60', 'availability_90', 'availability_365', 
            'number_of_reviews', 'review_scores_rating','review_scores_accuracy', 
            'review_scores_cleanliness','review_scores_checkin', 'review_scores_communication',
            'review_scores_location', 'review_scores_value', 'calculated_host_listings_count', 
            'reviews_per_month', 'price_y', 'price_mod', 'entire_home_apt', 'private_room', 
            'shared_room', 'apartment', 'bed_breakfast', 'boat', 'bungalow', 'cabin',
            'camper_rv', 'castle', 'cave', 'codominium', 'dorm', 'house','lighthouse', 'loft', 
            'other', 'tent', 'townhouse', 'treehouse', 'villa', 'yurt']
bnb_list_full =  bnb_list_full[num_cols]
test.isnull().sum()
# Out:
# host_total_listings_count            2
# latitude                             0
# longitude                            0
# is_location_exact                    0
# accommodates                         0
# bathrooms                           48
# bedrooms                             6
# beds                                10
# amenities                            0
# square_feet                       8417
# price                                0
# guests_included                      0
# extra_people                         0
# minimum_nights                       0
# maximum_nights                       0
# availability_30                      0
# availability_60                      0
# availability_90                      0
# availability_365                     0
# number_of_reviews                    0
# review_scores_rating                 0
# review_scores_accuracy               0
# review_scores_cleanliness            0
# review_scores_checkin                0
# review_scores_communication          0
# review_scores_location               0
# review_scores_value                  0
# calculated_host_listings_count       0
# reviews_per_month                 2223
# price_y                           2227
# price_mod                            0
# entire_home_apt                      0
# private_room                         0
# shared_room                          0
# apartment                            0
# bed_breakfast                        0
# boat                                 0
# bungalow                             0
# cabin                                0
# camper_rv                            0
# castle                               0
# cave                                 0
# codominium                           0
# dorm                                 0
# house                                0
# lighthouse                           0
# loft                                 0
# other                                0
# tent                                 0
# townhouse                            0
# treehouse                            0
# villa                                0
# yurt                                 0
# dtype: int64

# %% [markdown]
# Fill some missing values with logical replacements.
#
# - 2 missing from host_total_listings_count - replace with 1
# - 48 missing from bathrooms - replace with 1, considering there is likely a bathroom somewhere
# - 6 missing from bedrooms - replace with 0, there probably isn't an actual bed, maybe something to sleep on
# - 10 missing from beds - replace with 1, there is probably somewhere to sleep, but maybe not much
# - 8417 missing from square_feet - remove feature? - would certainly be useful in actual real estate listings
# - 2223 missing from reviews_per_month - replace with 0, since there are probably none or very few reviews

# %%
bnb_list_full.host_total_listings_count.fillna(1, inplace=True)
bnb_list_full.bathrooms.fillna(1, inplace=True)
bnb_list_full.bedrooms.fillna(0, inplace=True)
bnb_list_full.beds.fillna(1, inplace=True)
# bnb_list_full[[x for x in bnb_list_full.columns.values if x != 'square_feet']]
bnb_list_full.reviews_per_month.fillna(0, inplace=True)
bnb_list_full.isnull().sum()
# Out:
# host_total_listings_count            0
# latitude                             0
# longitude                            0
# accommodates                         0
# bathrooms                            0
# bedrooms                             0
# beds                                 0
# amenities                            0
# price                                0
# guests_included                      0
# extra_people                         0
# minimum_nights                       0
# maximum_nights                       0
# availability_30                      0
# availability_60                      0
# availability_90                      0
# availability_365                     0
# number_of_reviews                    0
# review_scores_rating                 0
# review_scores_accuracy               0
# review_scores_cleanliness            0
# review_scores_checkin                0
# review_scores_communication          0
# review_scores_location               0
# review_scores_value                  0
# calculated_host_listings_count       0
# reviews_per_month                    0
# price_y                           2227
# price_mod                            0
# entire_home_apt                      0
# private_room                         0
# shared_room                          0
# apartment                            0
# bed_breakfast                        0
# boat                                 0
# bungalow                             0
# cabin                                0
# camper_rv                            0
# castle                               0
# cave                                 0
# codominium                           0
# dorm                                 0
# house                                0
# lighthouse                           0
# loft                                 0
# other                                0
# tent                                 0
# townhouse                            0
# treehouse                            0
# villa                                0
# yurt                                 0
# dtype: int64

# %%
pd.to_pickle(bnb_list_full, './bnb_list_full')

# %% [markdown]
# #### Preliminary modelling of airbnb listing data

# %%
# from sklearn.metrics import 
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, RidgeCV
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

import seaborn as sns

# %% [markdown]
# Just to test out the predicitve ability of some of the features, I am going t run through some raw tests to predict the price of the airbnb rental at a per night rate. I am going to target the modified prices, prices_mod, which are a combination of the declared rate in the summary table and the calculated per night average rate of prices in an attempt to capture the range of values for weeknights, weekends, and holidays.
#
# We can compare these results to the summary prices, which is another feature in the df.

# %%
#bnb_list_full = bnb_list_full.applymap(conv_to_float)
y = bnb_list_full.price_mod.values
drop_cols = ['price_mod', 'price_y', 'price', 'latitude', 'longitude', 
             'amenities']
keep_cols = [x for x in bnb_list_full.columns.values if x not in drop_cols]
X = bnb_list_full[keep_cols]

ss = StandardScaler()
Xs = ss.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(Xs, y, test_size=0.3, random_state=2)

linreg = LinearRegression()
linreg.fit(X_train, y_train)
y_pred = linreg.predict(X_test)
linreg.score(X_test, y_test)
# Out:
# -14188115428509.605

# %%
ridge = RidgeCV(alphas=[0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000, 10000])
ridge.fit(X_train, y_train)
y_pred = ridge.predict(X_test)
print ridge.
ridge.score(X_test, y_test)
# Out:
# [  1.36005975e+00   7.02485601e+01   3.95336417e+01   1.12405309e+02
#   -1.34965909e+01  -3.40998300e+01  -4.59862806e+00  -9.36927628e+00
#   -2.97080510e-01   9.52218569e+00   1.40387254e+01   5.16039837e+00
#   -1.33923229e+01  -2.93527370e+00   2.35547988e+00   6.10930051e+00
#    6.90493750e+00   2.26140040e+00  -2.96932846e+00   6.71370448e+00
#   -6.28575277e+00  -2.49710248e+01  -2.07762879e+01   2.32739644e+01
#   -1.61030821e+01  -1.63404135e+01   5.82333115e+00   3.02999178e+00
#   -3.85564175e+00   1.74128276e+00   1.92060603e-01   7.20479521e-01
#   -3.51052964e-27  -3.51052964e-27   3.00330891e+00  -8.57747101e+00
#   -1.37993875e+01  -6.61660808e-02   1.22917416e+01   6.02203663e+00
#    5.87908450e-27   6.51553536e-01  -3.15792069e-01   3.91271512e+01
#    5.87908450e-27]
# 0.12640864411365249

# %%
rfr = RandomForestRegressor(n_estimators=1000, n_jobs=2)
rfr.fit(X_train, y_train)
y_pred = rfr.predict(X_test)
rfr.score(X_test, y_test)
# Out:
# 0.16453424335029887

# %%
xgb = XGBRegressor(max_depth=6, n_estimators=1000, reg_alpha=100)
xgb.fit(X_train, y_train)
y_pred = xgb.predict(X_test)
xgb.score(X_test, y_test)
# Out:
# 0.17482356762217

# %%
sns.regplot(y_pred, y_test)
plt.plot(range(0,10000), range(0,10000));
